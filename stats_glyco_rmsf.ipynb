# %%
import pandas as pd
import matplotlib.patches as mpatches
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
import matplotlib.pyplot as plt
from pingouin import pairwise_tukey
from pingouin import pairwise_tukey
from openpyxl import load_workbook

path=r'/Users/zrollins/Documents/Documents/TCR_glyco/RMSF_Stats.xlsx'
book = load_workbook(path)
writer=pd.ExcelWriter(path, engine = 'openpyxl')
writer.book=book

atoms = []
CDR1a_100_M1, CDR2a_100_M1, CDR3a_100_M1, CDR1b_100_M1, CDR2b_100_M1, CDR3b_100_M1 = [], [], [], [], [], []
MHCa_100_M1, MHCb_100_M1, pep_100_M1= [], [], []
CDR1a_100_GVA, CDR2a_100_GVA, CDR3a_100_GVA, CDR1b_100_GVA, CDR2b_100_GVA, CDR3b_100_GVA = [], [], [], [], [], []
MHCa_100_GVA, MHCb_100_GVA, pep_100_GVA= [], [], []
# 100 ns Glyco

            
with open("/Users/zrollins/Documents/Documents/TCR_glyco/glyco/70/rmsf_CDR1a.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            CDR1a_100_M1.append(float(cols[1]))
            
with open("/Users/zrollins/Documents/Documents/TCR_glyco/glyco/70/rmsf_CDR2a.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            CDR2a_100_M1.append(float(cols[1]))
            
with open("/Users/zrollins/Documents/Documents/TCR_glyco/glyco/70/rmsf_CDR3a.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            CDR3a_100_M1.append(float(cols[1]))
            
with open("/Users/zrollins/Documents/Documents/TCR_glyco/glyco/70/rmsf_CDR1b.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            CDR1b_100_M1.append(float(cols[1]))
            
with open("/Users/zrollins/Documents/Documents/TCR_glyco/glyco/70/rmsf_CDR2b.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            CDR2b_100_M1.append(float(cols[1]))
            
with open("/Users/zrollins/Documents/Documents/TCR_glyco/glyco/70/rmsf_CDR3b.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            CDR3b_100_M1.append(float(cols[1]))
            
with open("/Users/zrollins/Documents/Documents/TCR_glyco/glyco/70/rmsf_MHCa.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            MHCa_100_M1.append(float(cols[1]))
        
with open("/Users/zrollins/Documents/Documents/TCR_glyco/glyco/70/rmsf_MHCb.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            MHCb_100_M1.append(float(cols[1]))
            
with open("/Users/zrollins/Documents/Documents/TCR_glyco/glyco/70/rmsf_pep.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            pep_100_M1.append(float(cols[1]))
with open("/Users/zrollins/Documents/Documents/TCR_glyco/dglyco/70/rmsf_CDR1a.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            CDR1a_100_GVA.append(float(cols[1]))
            
with open("/Users/zrollins/Documents/Documents/TCR_glyco/dglyco/70/rmsf_CDR2a.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            CDR2a_100_GVA.append(float(cols[1]))
            
with open("/Users/zrollins/Documents/Documents/TCR_glyco/dglyco/70/rmsf_CDR3a.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            CDR3a_100_GVA.append(float(cols[1]))
            
with open("/Users/zrollins/Documents/Documents/TCR_glyco/dglyco/70/rmsf_CDR1b.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            CDR1b_100_GVA.append(float(cols[1]))
            
with open("/Users/zrollins/Documents/Documents/TCR_glyco/dglyco/70/rmsf_CDR2b.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            CDR2b_100_GVA.append(float(cols[1]))
            
with open("/Users/zrollins/Documents/Documents/TCR_glyco/dglyco/70/rmsf_CDR3b.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            CDR3b_100_GVA.append(float(cols[1]))
            
with open("/Users/zrollins/Documents/Documents/TCR_glyco/dglyco/70/rmsf_MHCa.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            MHCa_100_GVA.append(float(cols[1]))
        
with open("/Users/zrollins/Documents/Documents/TCR_glyco/dglyco/70/rmsf_MHCb.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            MHCb_100_GVA.append(float(cols[1]))
            
with open("/Users/zrollins/Documents/Documents/TCR_glyco/dglyco/70/rmsf_pep.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            pep_100_GVA.append(float(cols[1]))
            
            
atoms = []

CDR1a_95_M1, CDR2a_95_M1, CDR3a_95_M1, CDR1b_95_M1, CDR2b_95_M1, CDR3b_95_M1 = [], [], [], [], [], []
MHCa_95_M1, MHCb_95_M1, pep_95_M1= [], [], []
CDR1a_95_GVA, CDR2a_95_GVA, CDR3a_95_GVA, CDR1b_95_GVA, CDR2b_95_GVA, CDR3b_95_GVA = [], [], [], [], [], []
MHCa_95_GVA, MHCb_95_GVA, pep_95_GVA= [], [], []
# 95 ns Glyco


with open("/Users/zrollins/Documents/Documents/TCR_glyco/glyco/60/rmsf_CDR1a.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            CDR1a_95_M1.append(float(cols[1]))
            
with open("/Users/zrollins/Documents/Documents/TCR_glyco/glyco/60/rmsf_CDR2a.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            CDR2a_95_M1.append(float(cols[1]))
            
with open("/Users/zrollins/Documents/Documents/TCR_glyco/glyco/60/rmsf_CDR3a.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            CDR3a_95_M1.append(float(cols[1]))
            
with open("/Users/zrollins/Documents/Documents/TCR_glyco/glyco/60/rmsf_CDR1b.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            CDR1b_95_M1.append(float(cols[1]))
            
with open("/Users/zrollins/Documents/Documents/TCR_glyco/glyco/60/rmsf_CDR2b.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            CDR2b_95_M1.append(float(cols[1]))
            
with open("/Users/zrollins/Documents/Documents/TCR_glyco/glyco/60/rmsf_CDR3b.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            CDR3b_95_M1.append(float(cols[1]))
            
with open("/Users/zrollins/Documents/Documents/TCR_glyco/glyco/60/rmsf_MHCa.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            MHCa_95_M1.append(float(cols[1]))
        
with open("/Users/zrollins/Documents/Documents/TCR_glyco/glyco/60/rmsf_MHCb.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            MHCb_95_M1.append(float(cols[1]))
            
with open("/Users/zrollins/Documents/Documents/TCR_glyco/glyco/60/rmsf_pep.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            pep_95_M1.append(float(cols[1]))
with open("/Users/zrollins/Documents/Documents/TCR_glyco/dglyco/60/rmsf_CDR1a.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            CDR1a_95_GVA.append(float(cols[1]))
            
with open("/Users/zrollins/Documents/Documents/TCR_glyco/dglyco/60/rmsf_CDR2a.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            CDR2a_95_GVA.append(float(cols[1]))
            
with open("/Users/zrollins/Documents/Documents/TCR_glyco/dglyco/60/rmsf_CDR3a.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            CDR3a_95_GVA.append(float(cols[1]))
            
with open("/Users/zrollins/Documents/Documents/TCR_glyco/dglyco/60/rmsf_CDR1b.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            CDR1b_95_GVA.append(float(cols[1]))
            
with open("/Users/zrollins/Documents/Documents/TCR_glyco/dglyco/60/rmsf_CDR2b.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            CDR2b_95_GVA.append(float(cols[1]))
            
with open("/Users/zrollins/Documents/Documents/TCR_glyco/dglyco/60/rmsf_CDR3b.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            CDR3b_95_GVA.append(float(cols[1]))
            
with open("/Users/zrollins/Documents/Documents/TCR_glyco/dglyco/60/rmsf_MHCa.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            MHCa_95_GVA.append(float(cols[1]))
        
with open("/Users/zrollins/Documents/Documents/TCR_glyco/dglyco/60/rmsf_MHCb.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            MHCb_95_GVA.append(float(cols[1]))
            
with open("/Users/zrollins/Documents/Documents/TCR_glyco/dglyco/60/rmsf_pep.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            pep_95_GVA.append(float(cols[1]))
            
            
atoms = []
CDR1a_90_M1, CDR2a_90_M1, CDR3a_90_M1, CDR1b_90_M1, CDR2b_90_M1, CDR3b_90_M1 = [], [], [], [], [], []
MHCa_90_M1, MHCb_90_M1, pep_90_M1= [], [], []
CDR1a_90_GVA, CDR2a_90_GVA, CDR3a_90_GVA, CDR1b_90_GVA, CDR2b_90_GVA, CDR3b_90_GVA = [], [], [], [], [], []
MHCa_90_GVA, MHCb_90_GVA, pep_90_GVA= [], [], []


# 90 ns Glyco

with open("/Users/zrollins/Documents/Documents/TCR_glyco/glyco/50/rmsf_CDR1a.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            CDR1a_90_M1.append(float(cols[1]))
            
with open("/Users/zrollins/Documents/Documents/TCR_glyco/glyco/50/rmsf_CDR2a.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            CDR2a_90_M1.append(float(cols[1]))
            
with open("/Users/zrollins/Documents/Documents/TCR_glyco/glyco/50/rmsf_CDR3a.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            CDR3a_90_M1.append(float(cols[1]))
            
with open("/Users/zrollins/Documents/Documents/TCR_glyco/glyco/50/rmsf_CDR1b.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            CDR1b_90_M1.append(float(cols[1]))
            
with open("/Users/zrollins/Documents/Documents/TCR_glyco/glyco/50/rmsf_CDR2b.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            CDR2b_90_M1.append(float(cols[1]))
            
with open("/Users/zrollins/Documents/Documents/TCR_glyco/glyco/50/rmsf_CDR3b.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            CDR3b_90_M1.append(float(cols[1]))
            
with open("/Users/zrollins/Documents/Documents/TCR_glyco/glyco/50/rmsf_MHCa.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            MHCa_90_M1.append(float(cols[1]))
        
with open("/Users/zrollins/Documents/Documents/TCR_glyco/glyco/50/rmsf_MHCb.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            MHCb_90_M1.append(float(cols[1]))
            
with open("/Users/zrollins/Documents/Documents/TCR_glyco/glyco/50/rmsf_pep.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            pep_90_M1.append(float(cols[1]))
with open("/Users/zrollins/Documents/Documents/TCR_glyco/dglyco/50/rmsf_CDR1a.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            CDR1a_90_GVA.append(float(cols[1]))
            
with open("/Users/zrollins/Documents/Documents/TCR_glyco/dglyco/50/rmsf_CDR2a.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            CDR2a_90_GVA.append(float(cols[1]))
            
with open("/Users/zrollins/Documents/Documents/TCR_glyco/dglyco/50/rmsf_CDR3a.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            CDR3a_90_GVA.append(float(cols[1]))
            
with open("/Users/zrollins/Documents/Documents/TCR_glyco/dglyco/50/rmsf_CDR1b.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            CDR1b_90_GVA.append(float(cols[1]))
            
with open("/Users/zrollins/Documents/Documents/TCR_glyco/dglyco/50/rmsf_CDR2b.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            CDR2b_90_GVA.append(float(cols[1]))
            
with open("/Users/zrollins/Documents/Documents/TCR_glyco/dglyco/50/rmsf_CDR3b.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            CDR3b_90_GVA.append(float(cols[1]))
            
with open("/Users/zrollins/Documents/Documents/TCR_glyco/dglyco/50/rmsf_MHCa.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            MHCa_90_GVA.append(float(cols[1]))
        
with open("/Users/zrollins/Documents/Documents/TCR_glyco/dglyco/50/rmsf_MHCb.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            MHCb_90_GVA.append(float(cols[1]))
            
with open("/Users/zrollins/Documents/Documents/TCR_glyco/dglyco/50/rmsf_pep.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            pep_90_GVA.append(float(cols[1]))
            
            
#Plot


cdr1a_M1 = {'100 ns CDR1a':CDR1a_100_M1,'95 ns CDR1a':CDR1a_95_M1,'90 ns CDR1a':CDR1a_90_M1}
cdr1a_M1 = pd.DataFrame(cdr1a_M1)
cols=['100 ns CDR1a','95 ns CDR1a','90 ns CDR1a']
cdr1a_M1['CDR1a'] = cdr1a_M1[cols].astype(float).mean(axis=1)
cdr1a_M1['CDR1a SEM'] = cdr1a_M1[cols].astype(float).sem(axis=1)
cdr1a_M1.loc['avg']=cdr1a_M1.mean()

cdr2a_M1 = {'100 ns CDR2a':CDR2a_100_M1,'95 ns CDR2a':CDR2a_95_M1,'90 ns CDR2a':CDR2a_90_M1}
cdr2a_M1 = pd.DataFrame(cdr2a_M1)
cols2=['100 ns CDR2a','95 ns CDR2a','90 ns CDR2a']
cdr2a_M1['CDR2a'] = cdr2a_M1[cols2].astype(float).mean(axis=1)
cdr2a_M1['CDR2a SEM'] = cdr2a_M1[cols2].astype(float).sem(axis=1)
cdr2a_M1.loc['avg']=cdr2a_M1.mean()

cdr3a_M1 = {'100 ns CDR3a':CDR3a_100_M1,'95 ns CDR3a':CDR3a_95_M1,'90 ns CDR3a':CDR3a_90_M1}
cdr3a_M1 = pd.DataFrame(cdr3a_M1)
cols3=['100 ns CDR3a','95 ns CDR3a','90 ns CDR3a']
cdr3a_M1['CDR3a'] = cdr3a_M1[cols3].astype(float).mean(axis=1)
cdr3a_M1['CDR3a SEM'] = cdr3a_M1[cols3].astype(float).sem(axis=1)
cdr3a_M1.loc['avg']=cdr3a_M1.mean()

cdr1b_M1 = {'100 ns CDR1b':CDR1b_100_M1,'95 ns CDR1b':CDR1b_95_M1,'90 ns CDR1b':CDR1b_90_M1}
cdr1b_M1 = pd.DataFrame(cdr1b_M1)
cols4=['100 ns CDR1b','95 ns CDR1b','90 ns CDR1b']
cdr1b_M1['CDR1b'] = cdr1b_M1[cols4].astype(float).mean(axis=1)
cdr1b_M1['CDR1b SEM'] = cdr1b_M1[cols4].astype(float).sem(axis=1)
cdr1b_M1.loc['avg']=cdr1b_M1.mean()

cdr2b_M1 = {'100 ns CDR2b':CDR2b_100_M1,'95 ns CDR2b':CDR2b_95_M1,'90 ns CDR2b':CDR2b_90_M1}
cdr2b_M1 = pd.DataFrame(cdr2b_M1)
cols5=['100 ns CDR2b','95 ns CDR2b','90 ns CDR2b']
cdr2b_M1['CDR2b'] = cdr2b_M1[cols5].astype(float).mean(axis=1)
cdr2b_M1['CDR2b SEM'] = cdr2b_M1[cols5].astype(float).sem(axis=1)
cdr2b_M1.loc['avg']=cdr2b_M1.mean()

cdr3b_M1 = {'100 ns CDR3b':CDR3b_100_M1,'95 ns CDR3b':CDR3b_95_M1,'90 ns CDR3b':CDR3b_90_M1}
cdr3b_M1 = pd.DataFrame(cdr3b_M1)
cols6=['100 ns CDR3b','95 ns CDR3b','90 ns CDR3b']
cdr3b_M1['CDR3b'] = cdr3b_M1[cols6].astype(float).mean(axis=1)
cdr3b_M1['CDR3b SEM'] = cdr3b_M1[cols6].astype(float).sem(axis=1)
cdr3b_M1.loc['avg']=cdr3b_M1.mean()

mhca_M1 = {'100 ns MHCa':MHCa_100_M1,'95 ns MHCa':MHCa_95_M1,'90 ns MHCa':MHCa_90_M1}
mhca_M1 = pd.DataFrame(mhca_M1)
cols7=['100 ns MHCa','95 ns MHCa','90 ns MHCa']
mhca_M1['MHCa'] = mhca_M1[cols7].astype(float).mean(axis=1)
mhca_M1['MHCa SEM'] = mhca_M1[cols7].astype(float).sem(axis=1)
mhca_M1.loc['avg']=mhca_M1.mean()

mhcb_M1 = {'100 ns MHCb':MHCb_100_M1,'95 ns MHCb':MHCb_95_M1,'90 ns MHCb':MHCb_90_M1}
mhcb_M1 = pd.DataFrame(mhcb_M1)
cols8=['100 ns MHCb','95 ns MHCb','90 ns MHCb']
mhcb_M1['MHCb'] = mhcb_M1[cols8].astype(float).mean(axis=1)
mhcb_M1['MHCb SEM'] = mhcb_M1[cols8].astype(float).sem(axis=1)
mhcb_M1.loc['avg']=mhcb_M1.mean()

pep_M1 = {'100 ns pep':pep_100_M1,'95 ns pep':pep_95_M1,'90 ns pep':pep_90_M1 }
pep_M1 = pd.DataFrame(pep_M1)
cols9=['100 ns pep','95 ns pep','90 ns pep']
pep_M1['Glyco'] = pep_M1[cols9].astype(float).mean(axis=1)
pep_M1['Glyco SEM'] = pep_M1[cols9].astype(float).sem(axis=1)
pep_M1.loc['avg']=pep_M1.mean()

#Plot

cdr1a_GVA = {'100 ns CDR1a':CDR1a_100_GVA,'95 ns CDR1a':CDR1a_95_GVA,'90 ns CDR1a':CDR1a_90_GVA}
cdr1a_GVA = pd.DataFrame(cdr1a_GVA)
cols=['100 ns CDR1a','95 ns CDR1a','90 ns CDR1a']
cdr1a_GVA['CDR1a'] = cdr1a_GVA[cols].astype(float).mean(axis=1)
cdr1a_GVA['CDR1a SEM'] = cdr1a_GVA[cols].astype(float).sem(axis=1)
cdr1a_GVA.loc['avg']=cdr1a_GVA.mean()

cdr2a_GVA = {'100 ns CDR2a':CDR2a_100_GVA,'95 ns CDR2a':CDR2a_95_GVA,'90 ns CDR2a':CDR2a_90_GVA}
cdr2a_GVA = pd.DataFrame(cdr2a_GVA)
cols2=['100 ns CDR2a','95 ns CDR2a','90 ns CDR2a']
cdr2a_GVA['CDR2a'] = cdr2a_GVA[cols2].astype(float).mean(axis=1)
cdr2a_GVA['CDR2a SEM'] = cdr2a_GVA[cols2].astype(float).sem(axis=1)
cdr2a_GVA.loc['avg']=cdr2a_GVA.mean()

cdr3a_GVA = {'100 ns CDR3a':CDR3a_100_GVA,'95 ns CDR3a':CDR3a_95_GVA,'90 ns CDR3a':CDR3a_90_GVA}
cdr3a_GVA = pd.DataFrame(cdr3a_GVA)
cols3=['100 ns CDR3a','95 ns CDR3a','90 ns CDR3a']
cdr3a_GVA['CDR3a'] = cdr3a_GVA[cols3].astype(float).mean(axis=1)
cdr3a_GVA['CDR3a SEM'] = cdr3a_GVA[cols3].astype(float).sem(axis=1)
cdr3a_GVA.loc['avg']=cdr3a_GVA.mean()

cdr1b_GVA = {'100 ns CDR1b':CDR1b_100_GVA,'95 ns CDR1b':CDR1b_95_GVA,'90 ns CDR1b':CDR1b_90_GVA}
cdr1b_GVA = pd.DataFrame(cdr1b_GVA)
cols4=['100 ns CDR1b','95 ns CDR1b','90 ns CDR1b']
cdr1b_GVA['CDR1b'] = cdr1b_GVA[cols4].astype(float).mean(axis=1)
cdr1b_GVA['CDR1b SEM'] = cdr1b_GVA[cols4].astype(float).sem(axis=1)
cdr1b_GVA.loc['avg']=cdr1b_GVA.mean()

cdr2b_GVA = {'100 ns CDR2b':CDR2b_100_GVA,'95 ns CDR2b':CDR2b_95_GVA,'90 ns CDR2b':CDR2b_90_GVA}
cdr2b_GVA = pd.DataFrame(cdr2b_GVA)
cols5=['100 ns CDR2b','95 ns CDR2b','90 ns CDR2b']
cdr2b_GVA['CDR2b'] = cdr2b_GVA[cols5].astype(float).mean(axis=1)
cdr2b_GVA['CDR2b SEM'] = cdr2b_GVA[cols5].astype(float).sem(axis=1)
cdr2b_GVA.loc['avg']=cdr2b_GVA.mean()

cdr3b_GVA = {'100 ns CDR3b':CDR3b_100_GVA,'95 ns CDR3b':CDR3b_95_GVA,'90 ns CDR3b':CDR3b_90_GVA}
cdr3b_GVA = pd.DataFrame(cdr3b_GVA)
cols6=['100 ns CDR3b','95 ns CDR3b','90 ns CDR3b']
cdr3b_GVA['CDR3b'] = cdr3b_GVA[cols6].astype(float).mean(axis=1)
cdr3b_GVA['CDR3b SEM'] = cdr3b_GVA[cols6].astype(float).sem(axis=1)
cdr3b_GVA.loc['avg']=cdr3b_GVA.mean()

mhca_GVA = {'100 ns MHCa':MHCa_100_GVA,'95 ns MHCa':MHCa_95_GVA,'90 ns MHCa':MHCa_90_GVA}
mhca_GVA = pd.DataFrame(mhca_GVA)
cols7=['100 ns MHCa','95 ns MHCa','90 ns MHCa']
mhca_GVA['MHCa'] = mhca_GVA[cols7].astype(float).mean(axis=1)
mhca_GVA['MHCa SEM'] = mhca_GVA[cols7].astype(float).sem(axis=1)
mhca_GVA.loc['avg']=mhca_GVA.mean()

mhcb_GVA = {'100 ns MHCb':MHCb_100_GVA,'95 ns MHCb':MHCb_95_GVA,'90 ns MHCb':MHCb_90_GVA}
mhcb_GVA = pd.DataFrame(mhcb_GVA)
cols8=['100 ns MHCb','95 ns MHCb','90 ns MHCb']
mhcb_GVA['MHCb'] = mhcb_GVA[cols8].astype(float).mean(axis=1)
mhcb_GVA['MHCb SEM'] = mhcb_GVA[cols8].astype(float).sem(axis=1)
mhcb_GVA.loc['avg']=mhcb_GVA.mean()

pep_GVA = {'100 ns pep':pep_100_GVA,'95 ns pep':pep_95_GVA,'90 ns pep':pep_90_GVA }
pep_GVA = pd.DataFrame(pep_GVA)
cols9=['100 ns pep','95 ns pep','90 ns pep']
pep_GVA['GVA'] = pep_GVA[cols9].astype(float).mean(axis=1)
pep_GVA['GVA SEM'] = pep_GVA[cols9].astype(float).sem(axis=1)
pep_GVA.loc['avg']=pep_GVA.mean()

cdr1a = pd.DataFrame()
cdr1a['Deglycosylated'] = cdr1a_M1['CDR1a']
cdr1a['Glycosylated'] = cdr1a_GVA['CDR1a']

cdr2a = pd.DataFrame()
cdr2a['Deglycosylated'] = cdr2a_M1['CDR2a']
cdr2a['Glycosylated'] = cdr2a_GVA['CDR2a']

cdr3a = pd.DataFrame()
cdr3a['Deglycosylated'] = cdr3a_M1['CDR3a']
cdr3a['Glycosylated'] = cdr3a_GVA['CDR3a']

cdr1b = pd.DataFrame()
cdr1b['Deglycosylated'] = cdr1b_M1['CDR1b']
cdr1b['Glycosylated'] = cdr1b_GVA['CDR1b']

cdr2b = pd.DataFrame()
cdr2b['Deglycosylated'] = cdr2b_M1['CDR2b']
cdr2b['Glycosylated'] = cdr2b_GVA['CDR2b']

cdr3b = pd.DataFrame()
cdr3b['Deglycosylated'] = cdr3b_M1['CDR3b']
cdr3b['Glycosylated'] = cdr3b_GVA['CDR3b']


mhca = pd.DataFrame()
mhca['Deglycosylated'] = mhca_M1['MHCa']
mhca['Glycosylated'] = mhca_GVA['MHCa']


mhcb = pd.DataFrame()
mhcb['Deglycosylated'] = mhcb_M1['MHCb']
mhcb['Glycosylated'] = mhcb_GVA['MHCb']


pep = pd.DataFrame()
pep['Deglycosylated'] = pep_M1['Glyco']
pep['Glycosylated'] = pep_GVA['GVA']

#RMSF_CNTRL_Pull: Statistics
##CDR1A
###One-Way ANOVA
f, p = stats.f_oneway(cdr1a.dropna()['Deglycosylated'],cdr1a.dropna()['Glycosylated'])
print('--------------------------------------------------')
print('One-Way ANOVA: CDR1A')
print('--------------------------------------------------')
print ('F=',f,',', 'PR(>F)=',p)

###Posthoc Tukey-Kramer Test
tk=cdr1a[['Deglycosylated','Glycosylated']].copy()
tk_melt=pd.melt(tk.reset_index(),id_vars=['index'], value_vars=['Deglycosylated','Glycosylated'])
tk_melt.columns=['index','Conditions','value']
tk_melt=tk_melt.dropna()
tk_melt=tk_melt.reset_index(drop=True)
m_comp=pairwise_tukey(data=tk_melt, dv='value', between ='Conditions')
m_comp.to_excel(writer,'CDR1a_Stats')
writer.save()

##cdr2a
###One-Way ANOVA
f, p = stats.f_oneway(cdr2a.dropna()['Deglycosylated'],cdr2a.dropna()['Glycosylated'])
print('--------------------------------------------------')
print('One-Way ANOVA: cdr2a')
print('--------------------------------------------------')
print ('F=',f,',', 'PR(>F)=',p)

###Posthoc Tukey-Kramer Test
tk=cdr2a[['Deglycosylated','Glycosylated']].copy()
tk_melt=pd.melt(tk.reset_index(),id_vars=['index'], value_vars=['Deglycosylated','Glycosylated'])
tk_melt.columns=['index','Conditions','value']
tk_melt=tk_melt.dropna()
tk_melt=tk_melt.reset_index(drop=True)
m_comp=pairwise_tukey(data=tk_melt, dv='value', between ='Conditions')
m_comp.to_excel(writer,'cdr2a_Stats')
writer.save()

##cdr3a
###One-Way ANOVA
f, p = stats.f_oneway(cdr3a.dropna()['Deglycosylated'],cdr3a.dropna()['Glycosylated'])
print('--------------------------------------------------')
print('One-Way ANOVA: cdr3a')
print('--------------------------------------------------')
print ('F=',f,',', 'PR(>F)=',p)

###Posthoc Tukey-Kramer Test
tk=cdr3a[['Deglycosylated','Glycosylated']].copy()
tk_melt=pd.melt(tk.reset_index(),id_vars=['index'], value_vars=['Deglycosylated','Glycosylated'])
tk_melt.columns=['index','Conditions','value']
tk_melt=tk_melt.dropna()
tk_melt=tk_melt.reset_index(drop=True)
m_comp=pairwise_tukey(data=tk_melt, dv='value', between ='Conditions')
m_comp.to_excel(writer,'cdr3a_Stats')
writer.save()

##cdr1b
###One-Way ANOVA
f, p = stats.f_oneway(cdr1b.dropna()['Deglycosylated'],cdr1b.dropna()['Glycosylated'])
print('--------------------------------------------------')
print('One-Way ANOVA: cdr1b')
print('--------------------------------------------------')
print ('F=',f,',', 'PR(>F)=',p)

###Posthoc Tukey-Kramer Test
tk=cdr1b[['Deglycosylated','Glycosylated']].copy()
tk_melt=pd.melt(tk.reset_index(),id_vars=['index'], value_vars=['Deglycosylated','Glycosylated'])
tk_melt.columns=['index','Conditions','value']
tk_melt=tk_melt.dropna()
tk_melt=tk_melt.reset_index(drop=True)
m_comp=pairwise_tukey(data=tk_melt, dv='value', between ='Conditions')
m_comp.to_excel(writer,'cdr1b_Stats')
writer.save()

##cdr2b
###One-Way ANOVA
f, p = stats.f_oneway(cdr2b.dropna()['Deglycosylated'],cdr2b.dropna()['Glycosylated'])
print('--------------------------------------------------')
print('One-Way ANOVA: cdr2b')
print('--------------------------------------------------')
print ('F=',f,',', 'PR(>F)=',p)

###Posthoc Tukey-Kramer Test
tk=cdr2b[['Deglycosylated','Glycosylated']].copy()
tk_melt=pd.melt(tk.reset_index(),id_vars=['index'], value_vars=['Deglycosylated','Glycosylated'])
tk_melt.columns=['index','Conditions','value']
tk_melt=tk_melt.dropna()
tk_melt=tk_melt.reset_index(drop=True)
m_comp=pairwise_tukey(data=tk_melt, dv='value', between ='Conditions')
m_comp.to_excel(writer,'cdr2b_Stats')
writer.save()

##cdr3b
###One-Way ANOVA
f, p = stats.f_oneway(cdr3b.dropna()['Deglycosylated'],cdr3b.dropna()['Glycosylated'])
print('--------------------------------------------------')
print('One-Way ANOVA: cdr3b')
print('--------------------------------------------------')
print ('F=',f,',', 'PR(>F)=',p)

###Posthoc Tukey-Kramer Test
tk=cdr3b[['Deglycosylated','Glycosylated']].copy()
tk_melt=pd.melt(tk.reset_index(),id_vars=['index'], value_vars=['Deglycosylated','Glycosylated'])
tk_melt.columns=['index','Conditions','value']
tk_melt=tk_melt.dropna()
tk_melt=tk_melt.reset_index(drop=True)
m_comp=pairwise_tukey(data=tk_melt, dv='value', between ='Conditions')
m_comp.to_excel(writer,'cdr3b_Stats')
writer.save()

##mhca
###One-Way ANOVA
f, p = stats.f_oneway(mhca.dropna()['Deglycosylated'],mhca.dropna()['Glycosylated'])
print('--------------------------------------------------')
print('One-Way ANOVA: mhca')
print('--------------------------------------------------')
print ('F=',f,',', 'PR(>F)=',p)

###Posthoc Tukey-Kramer Test
tk=mhca[['Deglycosylated','Glycosylated']].copy()
tk_melt=pd.melt(tk.reset_index(),id_vars=['index'], value_vars=['Deglycosylated','Glycosylated'])
tk_melt.columns=['index','Conditions','value']
tk_melt=tk_melt.dropna()
tk_melt=tk_melt.reset_index(drop=True)
m_comp=pairwise_tukey(data=tk_melt, dv='value', between ='Conditions')
m_comp.to_excel(writer,'mhca_Stats')
writer.save()

##mhcb
###One-Way ANOVA
f, p = stats.f_oneway(mhcb.dropna()['Deglycosylated'],mhcb.dropna()['Glycosylated'])
print('--------------------------------------------------')
print('One-Way ANOVA: mhcb')
print('--------------------------------------------------')
print ('F=',f,',', 'PR(>F)=',p)

###Posthoc Tukey-Kramer Test
tk=mhcb[['Deglycosylated','Glycosylated']].copy()
tk_melt=pd.melt(tk.reset_index(),id_vars=['index'], value_vars=['Deglycosylated','Glycosylated'])
tk_melt.columns=['index','Conditions','value']
tk_melt=tk_melt.dropna()
tk_melt=tk_melt.reset_index(drop=True)
m_comp=pairwise_tukey(data=tk_melt, dv='value', between ='Conditions')
m_comp.to_excel(writer,'mhcb_Stats')
writer.save()

##pep
###One-Way ANOVA
f, p = stats.f_oneway(pep.dropna()['Deglycosylated'],pep.dropna()['Glycosylated'])
print('--------------------------------------------------')
print('One-Way ANOVA: pep')
print('--------------------------------------------------')
print ('F=',f,',', 'PR(>F)=',p)

###Posthoc Tukey-Kramer Test
tk=pep[['Deglycosylated','Glycosylated']].copy()
tk_melt=pd.melt(tk.reset_index(),id_vars=['index'], value_vars=['Deglycosylated','Glycosylated'])
tk_melt.columns=['index','Conditions','value']
tk_melt=tk_melt.dropna()
tk_melt=tk_melt.reset_index(drop=True)
m_comp=pairwise_tukey(data=tk_melt, dv='value', between ='Conditions')
m_comp.to_excel(writer,'pep_Stats')
writer.save()
# Out:
# --------------------------------------------------
# One-Way ANOVA: CDR1A
# --------------------------------------------------
# F= 0.023984025482822902 , PR(>F)= 0.8770421340221582
# --------------------------------------------------
# One-Way ANOVA: cdr2a
# --------------------------------------------------
# F= 14.258134591470446 , PR(>F)= 0.0002184932232403931
# --------------------------------------------------
# One-Way ANOVA: cdr3a
# --------------------------------------------------
# F= 0.4748219064354987 , PR(>F)= 0.49127340461374835
# --------------------------------------------------
# One-Way ANOVA: cdr1b
# --------------------------------------------------
# F= 0.08593176617065783 , PR(>F)= 0.7696880542310828
# --------------------------------------------------
# One-Way ANOVA: cdr2b
# --------------------------------------------------
# F= 2.4022239717774907 , PR(>F)= 0.12266860053617587
# --------------------------------------------------
# One-Way ANOVA: cdr3b
# ...
