# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

#Chain A (MHC) vs Time
a, t = [], []

with open("/Users/zrollins/Documents/Documents/TCR_glyco/dglyco/A_RMSD.xvg") as f:
    #lines = (line for line in f if not line.startsiwith('#') if not line.startswith('$'))
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            t.append(float(cols[0]))
            a.append(float(cols[1]))

#Chain B (B2M) vs Time

            
b, t = [], []

with open("/Users/zrollins/Documents/Documents/TCR_glyco/dglyco/B_RMSD.xvg") as f:
    #lines = (line for line in f if not line.startsiwith('#') if not line.startswith('$'))
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            t.append(float(cols[0]))
            b.append(float(cols[1]))

#Chain C (GVA) vs Time

            
c, t = [], []

with open("/Users/zrollins/Documents/Documents/TCR_glyco/dglyco/C_RMSD.xvg") as f:
    #lines = (line for line in f if not line.startsiwith('#') if not line.startswith('$'))
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            t.append(float(cols[0]))
            c.append(float(cols[1]))

#Chain D (TCRa) vs Time

            
d, t = [], []

with open("/Users/zrollins/Documents/Documents/TCR_glyco/dglyco/D_RMSD.xvg") as f:
    #lines = (line for line in f if not line.startsiwith('#') if not line.startswith('$'))
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            t.append(float(cols[0]))
            d.append(float(cols[1]))
            
#Chain E (TCRb) vs Time

            
e, t = [], []

with open("/Users/zrollins/Documents/Documents/TCR_glyco/dglyco/E_RMSD.xvg") as f:
    #lines = (line for line in f if not line.startsiwith('#') if not line.startswith('$'))
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            t.append(float(cols[0]))
            e.append(float(cols[1]))
#TCR-peptide H_Number vs Time


#PLOT Chain RMSD

rmsd = {'Time (ns)': t,'MHCα':a,'β2M':b,'MART1':c,'TCRα':d,'TCRβ':e}
df = pd.DataFrame(rmsd)
#df['Peptide SMA']= df.iloc[:,1].rolling(window=200).mean()
#df['MHC SMA']= df.iloc[:,2].rolling(window=200).mean()
ax = plt.gca()
df.plot(kind='line',x='Time (ns)', y='MHCα', color='darkgreen', ax=ax)
df.plot(kind='line',x='Time (ns)', y='β2M', color= 'green', ax=ax)
df.plot(kind='line',x='Time (ns)', y='MART1', color='magenta', ax=ax)
df.plot(kind='line',x='Time (ns)', y='TCRα', color='blue', ax=ax)
df.plot(kind='line',x='Time (ns)', y='TCRβ', color='red', ax=ax)
ax.set_ylabel('RMSD (nm)', fontname = 'Arial', fontsize=20)
ax.set_xlabel('Time (ps)', fontname = 'Arial', fontsize=20)
ax.set_title('Deglycosylated Equilibration', fontname = 'Arial Black', fontsize=20)

plt.rc('xtick',labelsize=15)
plt.rc('ytick',labelsize=15)
plt.savefig('/Users/zrollins/Documents/Documents/TCR_glyco/dglyco/RMSD_dglyco.png', bbox_inches='tight', dpi=300)
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

#Chain A (MHC) vs Time
a, t = [], []

with open("/Users/zrollins/Documents/Documents/TCR_glyco/glyco/A_RMSD.xvg") as f:
    #lines = (line for line in f if not line.startsiwith('#') if not line.startswith('$'))
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            t.append(float(cols[0]))
            a.append(float(cols[1]))

#Chain B (B2M) vs Time

            
b, t = [], []

with open("/Users/zrollins/Documents/Documents/TCR_glyco/glyco/B_RMSD.xvg") as f:
    #lines = (line for line in f if not line.startsiwith('#') if not line.startswith('$'))
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            t.append(float(cols[0]))
            b.append(float(cols[1]))

#Chain C (GVA) vs Time

            
c, t = [], []

with open("/Users/zrollins/Documents/Documents/TCR_glyco/glyco/C_RMSD.xvg") as f:
    #lines = (line for line in f if not line.startsiwith('#') if not line.startswith('$'))
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            t.append(float(cols[0]))
            c.append(float(cols[1]))

#Chain D (TCRa) vs Time

            
d, t = [], []

with open("/Users/zrollins/Documents/Documents/TCR_glyco/glyco/D_RMSD.xvg") as f:
    #lines = (line for line in f if not line.startsiwith('#') if not line.startswith('$'))
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            t.append(float(cols[0]))
            d.append(float(cols[1]))
            
#Chain E (TCRb) vs Time

            
e, t = [], []

with open("/Users/zrollins/Documents/Documents/TCR_glyco/glyco/E_RMSD.xvg") as f:
    #lines = (line for line in f if not line.startsiwith('#') if not line.startswith('$'))
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            t.append(float(cols[0]))
            e.append(float(cols[1]))
            
g, t = [], []

with open("/Users/zrollins/Documents/Documents/TCR_glyco/glyco/G_RMSD.xvg") as f:
    #lines = (line for line in f if not line.startsiwith('#') if not line.startswith('$'))
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            t.append(float(cols[0]))
            g.append(float(cols[1]))
#TCR-peptide H_Number vs Time


#PLOT Chain RMSD

rmsd = {'Time (ns)': t,'MHCα':a,'β2M':b,'MART1':c,'TCRα':d,'TCRβ':e,'Glycans':g}
df = pd.DataFrame(rmsd)
#df['Peptide SMA']= df.iloc[:,1].rolling(window=200).mean()
#df['MHC SMA']= df.iloc[:,2].rolling(window=200).mean()
ax = plt.gca()
df.plot(kind='line',x='Time (ns)', y='MHCα', color='darkgreen', ax=ax)
df.plot(kind='line',x='Time (ns)', y='β2M', color= 'green', ax=ax)
df.plot(kind='line',x='Time (ns)', y='MART1', color='magenta', ax=ax)
df.plot(kind='line',x='Time (ns)', y='TCRα', color='blue', ax=ax)
df.plot(kind='line',x='Time (ns)', y='TCRβ', color='red', ax=ax)
df.plot(kind='line',x='Time (ns)', y='Glycans', color='orange', ax=ax)
ax.set_ylabel('RMSD (nm)', fontname = 'Arial', fontsize=20)
ax.set_xlabel('Time (ps)', fontname = 'Arial', fontsize=20)
ax.set_title('Glycosylated Equilibration', fontname = 'Arial Black', fontsize=20)

plt.rc('xtick',labelsize=15)
plt.rc('ytick',labelsize=15)
plt.savefig('/Users/zrollins/Documents/Documents/TCR_glyco/glyco/RMSD_glyco2.png', bbox_inches='tight', dpi=300)
plt.show()
