# %%
# SASA Bins
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
import matplotlib.pyplot as plt
from pingouin import pairwise_gameshowell
from pingouin import pairwise_gameshowell
from openpyxl import load_workbook




t, t1, t2, t3, t4, t5, t6, t7, t8, pep, pep1, pep2, pep3, pep4, pep5, pep6, pep7, pep8 = [],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[]
# 100 ns Glyco
with open("/Users/zrollins/Documents/Documents/TCR_glyco/glyco/70/SASA_pep.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            t.append(float(cols[0]))
            pep.append(float(cols[1]))
# 95 ns Glyco
with open("/Users/zrollins/Documents/Documents/TCR_glyco/glyco/60/SASA_pep.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            t1.append(float(cols[0]))
            pep1.append(float(cols[1]))
# 90 ns Glyco 
with open("/Users/zrollins/Documents/Documents/TCR_glyco/glyco/50/SASA_pep.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            t2.append(float(cols[0]))
            pep2.append(float(cols[1]))
# 100 ns Dglyco
with open("/Users/zrollins/Documents/Documents/TCR_glyco/dglyco/70/SASA_pep.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            t3.append(float(cols[0]))
            pep3.append(float(cols[1]))
# 95 ns Dglyco
with open("/Users/zrollins/Documents/Documents/TCR_glyco/dglyco/60/SASA_pep.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            t4.append(float(cols[0]))
            pep4.append(float(cols[1]))
# 90 ns Dglyco
with open("/Users/zrollins/Documents/Documents/TCR_glyco/dglyco/50/SASA_pep.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            t5.append(float(cols[0]))
            pep5.append(float(cols[1]))


print(np.amin(pep))
print(np.amax(pep))

#Bin SASA  
cut_bins = [12.0,12.1,12.2,12.3,12.4,12.5,12.6,12.7,12.8,12.9,13.0,13.1,13.2,13.3,13.4,13.5,13.6,13.7,13.8,13.9,14.0,14.1,14.2]

sasa={'Glyco (70ns)': pep}
df = pd.DataFrame(sasa)
s=pd.cut(df['Glyco (70ns)'], bins=cut_bins).value_counts(sort=False, normalize=True)

sasa1={'Glyco (60ns)': pep1}
df1 = pd.DataFrame(sasa1)
s1=pd.cut(df1['Glyco (60ns)'], bins=cut_bins).value_counts(sort=False, normalize=True)

sasa2={'Glyco (50ns)': pep2}
df2 = pd.DataFrame(sasa2)
s2=pd.cut(df2['Glyco (50ns)'], bins=cut_bins).value_counts(sort=False, normalize=True)

sasa3={'Dglyco (70ns)': pep3}
df3 = pd.DataFrame(sasa3)
s3=pd.cut(df3['Dglyco (70ns)'], bins=cut_bins).value_counts(sort=False, normalize=True)

sasa4={'Dglyco (60ns)': pep4}
df4 = pd.DataFrame(sasa4)
s4=pd.cut(df4['Dglyco (60ns)'], bins=cut_bins).value_counts(sort=False, normalize=True)

sasa5={'Dglyco (50ns)': pep5}
df5 = pd.DataFrame(sasa5)
s5=pd.cut(df5['Dglyco (50ns)'], bins=cut_bins).value_counts(sort=False, normalize=True)


#Plot SASA Frequency

SASA = s.to_frame()
s1 = s1.to_frame()
SASA['Glyco (60ns)'] = s1['Glyco (60ns)']
s2 = s2.to_frame()
SASA['Glyco (50ns)'] = s2['Glyco (50ns)']

s3 = s3.to_frame()
SASA['Dglyco (70ns)'] = s3['Dglyco (70ns)']
s4 = s4.to_frame()
SASA['Dglyco (60ns)'] = s4['Dglyco (60ns)']
s5 = s5.to_frame()
SASA['Dglyco (50ns)'] = s5['Dglyco (50ns)']



l = [12.0,12.1,12.2,12.3,12.4,12.5,12.6,12.7,12.8,12.9,13.0,13.1,13.2,13.3,13.4,13.5,13.6,13.7,13.8,13.9,14.0,14.1]
x = pd.Series(l)
SASA['SASA']= x.values
print(SASA)
M1 = ['Glyco (70ns)','Glyco (60ns)','Glyco (50ns)']
SASA['Glyco'] = SASA[M1].astype(float).mean(axis=1)
SASA['Glyco SEM'] = SASA[M1].astype(float).sem(axis=1)

Dglyco = ['Dglyco (70ns)','Dglyco (60ns)','Dglyco (50ns)']
SASA['Dglyco'] = SASA[Dglyco].astype(float).mean(axis=1)
SASA['Dglyco SEM'] = SASA[Dglyco].astype(float).sem(axis=1)


ax =plt.gca()
SASA.plot(kind='line',x='SASA', y='Glyco', yerr = 'Glyco SEM', color='green', ax=ax)
SASA.plot(kind='line',x='SASA', y='Dglyco', yerr = 'Dglyco SEM', color='black', ax=ax)
ax.set_ylabel(r'Probability Density ($\frac{N*s^2}{nm}$)',fontname= 'Arial', fontsize=20)
#ax.set_ylabel(r'Probability Density ($\frac{N*s^2}{nm}$)',fontname= 'Arial', fontsize=20)
ax.set_xlabel( r'Hydrophobic Surace Area ($\frac{nm}{N*s^2}$)', fontname= 'Arial', fontsize=20)
#ax.set_title('Peptide Solvent Accessible Surface Area', fontname='Arial', fontsize='20')
plt.rc('xtick',labelsize=15)
plt.rc('ytick',labelsize=15)
plt.savefig('/Users/zrollins/Documents/Documents/TCR_glyco/SASAtot.png',figsize=(6,4),bbox_inches='tight',dpi=300)
plt.show()
# Out:
# 11.904
# 13.943
#               Glyco (70ns)  Glyco (60ns)  Glyco (50ns)  Dglyco (70ns)  \
# (12.0, 12.1]      0.000577      0.000311      0.000151       0.017781
# (12.1, 12.2]      0.001730      0.002253      0.000578       0.034795
# (12.2, 12.3]      0.005274      0.005670      0.001808       0.057787
# (12.3, 12.4]      0.011701      0.011185      0.003968       0.086143
# (12.4, 12.5]      0.030405      0.020040      0.010548       0.102544
# (12.5, 12.6]      0.050264      0.042722      0.022929       0.127682
# (12.6, 12.7]      0.086190      0.065636      0.039706       0.136419
# (12.7, 12.8]      0.121869      0.091813      0.066201       0.116646
# (12.8, 12.9]      0.142551      0.117058      0.097042       0.099939
# (12.9, 13.0]      0.155158      0.129020      0.122934       0.077866
# (13.0, 13.1]      0.131427      0.131971      0.139510       0.059473
# (13.1, 13.2]      0.107614      0.113562      0.135215       0.038013
# ...
