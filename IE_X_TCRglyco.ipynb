# %%
#100ns MART1

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

#Data Arrays

t, t1, t2 = [], [], []
x, x1 = [], []
pep_c = []
pep_lj = []
MHC_c = []
MHC_lj = []

#COM Distance vs Time

with open("/Users/zrollins/Documents/Documents/TCR_glyco/dglyco/50/pullxcf.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            t1.append(float(cols[0]))
            x1.append(float(cols[1]))
x = x1[::10]

#TCR-MHC IE vs Time

with open("/Users/zrollins/Documents/Documents/TCR_glyco/dglyco/50/ie_DEA.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 3:
            t.append(float(cols[0]))
            MHC_c.append(float(cols[1]))
            MHC_lj.append(float(cols[2]))
            
#TCR-peptide IE vs Time

with open("/Users/zrollins/Documents/Documents/TCR_glyco/dglyco/50/ie_DEC.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 3:
            t2.append(float(cols[0]))
            pep_c.append(float(cols[1]))
            pep_lj.append(float(cols[2]))
            
print (len (x))
print(len (t1))
print(len (t))
print(len (t2))
print (len (MHC_c))
print (len (pep_c))
#PLOT Hbonds vs COM Distance

MHC_c = MHC_c[:len(MHC_c)-9]
MHC_lj = MHC_lj[:len(MHC_lj)-9]
pep_c = pep_c[:len(pep_c)-9]
pep_lj = pep_lj[:len(pep_lj)-9]



iex = {'COM Distance':x,'MHC-Coulombic':MHC_c,'MHC-LennardJones':MHC_lj,'Peptide_Coulombic':pep_c,'Peptide_LennardJones':pep_lj}

df=pd.DataFrame(iex)
df.to_excel('/Users/zrollins/Documents/Documents/TCR_glyco/dglyco/50/iex.xlsx')
df['MHC-Coulombic SMA']= df.iloc[:,1].rolling(window=100).mean()
df['MHC-LennardJones SMA']= df.iloc[:,2].rolling(window=100).mean()
ax = plt.gca()
df.plot(kind='line',x='COM Distance', y='MHC-Coulombic SMA', color='magenta', ax=ax)
df.plot(kind='line',x='COM Distance', y='MHC-LennardJones SMA', color='blue', ax=ax)
ax.set_ylabel('Interaction Energy (kJ/mol)')
ax.set_xlabel('COM Distance (nm)')
ax.legend(['Coulombic SMA','Lennard Jones SMA'])
ax.set_title('TCR-MHC Potential Mean Force (Deglycosylated, 50 ns)')
plt.xlim((5.9,10.0))
plt.savefig('/Users/zrollins/Documents/Documents/TCR_glyco/dglyco/50/iex_mhc.png')
plt.show()

df['MART1_Coulombic SMA']= df.iloc[:,3].rolling(window=100).mean()
df['MART1_LennardJones SMA']= df.iloc[:,4].rolling(window=100).mean()
ax = plt.gca()
df.plot(kind='line',x='COM Distance', y='MART1_Coulombic SMA', color='magenta', ax=ax)
df.plot(kind='line',x='COM Distance', y='MART1_LennardJones SMA', color='blue', ax=ax)
ax.set_ylabel('Interaction Energy (kJ/mol)')
ax.set_xlabel('COM Distance (nm)')
ax.legend(['Coulombic SMA','Lennard Jones SMA'])
ax.set_title('TCR-MART1 Potential Mean Force (Deglycosylated, 50 ns)')
plt.xlim((5.9,7.5))
plt.savefig('/Users/zrollins/Documents/Documents/TCR_glyco/dglyco/50/iex_pep.png')
plt.show()
# Out:
# 11368
# 113674
# 11377
# 11377
# 11377
# 11377

# %%
#100ns MART1

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

#Data Arrays

t, t1, t2 = [], [], []
x, x1 = [], []
pep_c = []
pep_lj = []
MHC_c = []
MHC_lj = []

#COM Distance vs Time

with open("/Users/zrollins/Documents/Documents/TCR_glyco/dglyco/60/pullxcf.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            t1.append(float(cols[0]))
            x1.append(float(cols[1]))
x = x1[::10]

#TCR-MHC IE vs Time

with open("/Users/zrollins/Documents/Documents/TCR_glyco/dglyco/60/ie_DEA.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 3:
            t.append(float(cols[0]))
            MHC_c.append(float(cols[1]))
            MHC_lj.append(float(cols[2]))
            
#TCR-peptide IE vs Time

with open("/Users/zrollins/Documents/Documents/TCR_glyco/dglyco/60/ie_DEC.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 3:
            t2.append(float(cols[0]))
            pep_c.append(float(cols[1]))
            pep_lj.append(float(cols[2]))
            
print (len (x))
print(len (t1))
print(len (t))
print(len (t2))
print (len (MHC_c))
print (len (pep_c))
#PLOT Hbonds vs COM Distance

MHC_c = MHC_c[:len(MHC_c)-17]
MHC_lj = MHC_lj[:len(MHC_lj)-17]
pep_c = pep_c[:len(pep_c)-17]
pep_lj = pep_lj[:len(pep_lj)-17]



iex = {'COM Distance':x,'MHC-Coulombic':MHC_c,'MHC-LennardJones':MHC_lj,'Peptide_Coulombic':pep_c,'Peptide_LennardJones':pep_lj}

df=pd.DataFrame(iex)
df.to_excel('/Users/zrollins/Documents/Documents/TCR_glyco/dglyco/60/iex.xlsx')
df['MHC-Coulombic SMA']= df.iloc[:,1].rolling(window=100).mean()
df['MHC-LennardJones SMA']= df.iloc[:,2].rolling(window=100).mean()
ax = plt.gca()
df.plot(kind='line',x='COM Distance', y='MHC-Coulombic SMA', color='magenta', ax=ax)
df.plot(kind='line',x='COM Distance', y='MHC-LennardJones SMA', color='blue', ax=ax)
ax.set_ylabel('Interaction Energy (kJ/mol)')
ax.set_xlabel('COM Distance (nm)')
ax.legend(['Coulombic SMA','Lennard Jones SMA'])
ax.set_title('TCR-MHC Potential Mean Force (Deglycosylated, 60 ns)')
plt.xlim((5.9,10.0))
plt.savefig('/Users/zrollins/Documents/Documents/TCR_glyco/dglyco/60/iex_mhc.png')
plt.show()

df['MART1_Coulombic SMA']= df.iloc[:,3].rolling(window=100).mean()
df['MART1_LennardJones SMA']= df.iloc[:,4].rolling(window=100).mean()
ax = plt.gca()
df.plot(kind='line',x='COM Distance', y='MART1_Coulombic SMA', color='magenta', ax=ax)
df.plot(kind='line',x='COM Distance', y='MART1_LennardJones SMA', color='blue', ax=ax)
ax.set_ylabel('Interaction Energy (kJ/mol)')
ax.set_xlabel('COM Distance (nm)')
ax.legend(['Coulombic SMA','Lennard Jones SMA'])
ax.set_title('TCR-MART1 Potential Mean Force (Deglycosylated, 60 ns)')
plt.xlim((5.9,7.5))
plt.savefig('/Users/zrollins/Documents/Documents/TCR_glyco/dglyco/60/iex_pep.png')
plt.show()
# Out:
# 4619
# 46188
# 4636
# 4636
# 4636
# 4636

# %%
#100ns MART1

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

#Data Arrays

t, t1, t2 = [], [], []
x, x1 = [], []
pep_c = []
pep_lj = []
MHC_c = []
MHC_lj = []

#COM Distance vs Time

with open("/Users/zrollins/Documents/Documents/TCR_glyco/dglyco/70/pullxcf.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            t1.append(float(cols[0]))
            x1.append(float(cols[1]))
x = x1[::10]

#TCR-MHC IE vs Time

with open("/Users/zrollins/Documents/Documents/TCR_glyco/dglyco/70/ie_DEA.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 3:
            t.append(float(cols[0]))
            MHC_c.append(float(cols[1]))
            MHC_lj.append(float(cols[2]))
            
#TCR-peptide IE vs Time

with open("/Users/zrollins/Documents/Documents/TCR_glyco/dglyco/70/ie_DEC.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 3:
            t2.append(float(cols[0]))
            pep_c.append(float(cols[1]))
            pep_lj.append(float(cols[2]))
            
print (len (x))
print(len (t1))
print(len (t))
print(len (t2))
print (len (MHC_c))
print (len (pep_c))
#PLOT Hbonds vs COM Distance

MHC_c = MHC_c[:len(MHC_c)-20]
MHC_lj = MHC_lj[:len(MHC_lj)-20]
pep_c = pep_c[:len(pep_c)-20]
pep_lj = pep_lj[:len(pep_lj)-20]



iex = {'COM Distance':x,'MHC-Coulombic':MHC_c,'MHC-LennardJones':MHC_lj,'Peptide_Coulombic':pep_c,'Peptide_LennardJones':pep_lj}

df=pd.DataFrame(iex)
df.to_excel('/Users/zrollins/Documents/Documents/TCR_glyco/dglyco/70/iex.xlsx')
df['MHC-Coulombic SMA']= df.iloc[:,1].rolling(window=100).mean()
df['MHC-LennardJones SMA']= df.iloc[:,2].rolling(window=100).mean()
ax = plt.gca()
df.plot(kind='line',x='COM Distance', y='MHC-Coulombic SMA', color='magenta', ax=ax)
df.plot(kind='line',x='COM Distance', y='MHC-LennardJones SMA', color='blue', ax=ax)
ax.set_ylabel('Interaction Energy (kJ/mol)')
ax.set_xlabel('COM Distance (nm)')
ax.legend(['Coulombic SMA','Lennard Jones SMA'])
ax.set_title('TCR-MHC Potential Mean Force (Deglycosylated, 70 ns)')
plt.xlim((5.9,10.0))
plt.savefig('/Users/zrollins/Documents/Documents/TCR_glyco/dglyco/70/iex_mhc.png')
plt.show()

df['MART1_Coulombic SMA']= df.iloc[:,3].rolling(window=100).mean()
df['MART1_LennardJones SMA']= df.iloc[:,4].rolling(window=100).mean()
ax = plt.gca()
df.plot(kind='line',x='COM Distance', y='MART1_Coulombic SMA', color='magenta', ax=ax)
df.plot(kind='line',x='COM Distance', y='MART1_LennardJones SMA', color='blue', ax=ax)
ax.set_ylabel('Interaction Energy (kJ/mol)')
ax.set_xlabel('COM Distance (nm)')
ax.legend(['Coulombic SMA','Lennard Jones SMA'])
ax.set_title('TCR-MART1 Potential Mean Force (Deglycosylated, 70 ns)')
plt.xlim((5.9,7.5))
plt.savefig('/Users/zrollins/Documents/Documents/TCR_glyco/dglyco/70/iex_pep.png')
plt.show()
# Out:
# 6632
# 66314
# 6652
# 6652
# 6652
# 6652

# %%
#100ns MART1

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

#Data Arrays

t, t1, t2, t3, t4, t5, t6 = [], [], [], [], [], [], []
x, x1 = [], []
pep_c = []
pep_lj = []
MHC_c = []
MHC_lj = []
aglyc_c = []
aglyc_lj = []
cglyc_c = []
cglyc_lj = []
deglyc_c = []
deglyc_lj = []
glyc_c = []
glyc_lj = []
#COM Distance vs Time

with open("/Users/zrollins/Documents/Documents/TCR_glyco/glyco/50/pullxcf.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            t1.append(float(cols[0]))
            x1.append(float(cols[1]))
x = x1[::10]

#TCR-MHC IE vs Time

with open("/Users/zrollins/Documents/Documents/TCR_glyco/glyco/50/ie_DEA.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 3:
            t.append(float(cols[0]))
            MHC_c.append(float(cols[1]))
            MHC_lj.append(float(cols[2]))
            
#TCR-peptide IE vs Time

with open("/Users/zrollins/Documents/Documents/TCR_glyco/glyco/50/ie_DEC.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 3:
            t2.append(float(cols[0]))
            pep_c.append(float(cols[1]))
            pep_lj.append(float(cols[2]))

#MHC-glyc IE vs Time

with open("/Users/zrollins/Documents/Documents/TCR_glyco/glyco/50/ieAglyc.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 3:
            t3.append(float(cols[0]))
            aglyc_c.append(float(cols[1]))
            aglyc_lj.append(float(cols[2]))

#Peptide-glyc IE vs Time

with open("/Users/zrollins/Documents/Documents/TCR_glyco/glyco/50/ieCglyc.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 3:
            t4.append(float(cols[0]))
            cglyc_c.append(float(cols[1]))
            cglyc_lj.append(float(cols[2]))
            
#TCR-glyc IE vs Time

with open("/Users/zrollins/Documents/Documents/TCR_glyco/glyco/50/ie_DEglyc.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 3:
            t5.append(float(cols[0]))
            deglyc_c.append(float(cols[1]))
            deglyc_lj.append(float(cols[2]))
            
#glyc-glyc IE vs Time

with open("/Users/zrollins/Documents/Documents/TCR_glyco/glyco/50/ie_glyc.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 3:
            t6.append(float(cols[0]))
            glyc_c.append(float(cols[1]))
            glyc_lj.append(float(cols[2]))
            
print (len (x))
#print(len (t1))
#print(len (t2))
print (len (MHC_c))
print (len (pep_c))
print (len (aglyc_c))
print (len (cglyc_c))
print (len (deglyc_c))
print (len (glyc_c))
#PLOT Hbonds vs COM Distance
x = x[:len(x)-53]
MHC_c = MHC_c[:len(MHC_c)-53]
MHC_lj = MHC_lj[:len(MHC_lj)-53]
pep_c = pep_c[:len(pep_c)-59]
pep_lj = pep_lj[:len(pep_lj)-59]
#aglyc_c = aglyc_c[:len(aglyc_c)-0]
#aglyc_lj = aglyc_lj[:len(aglyc_lj)-0]
cglyc_c = cglyc_c[:len(cglyc_c)-59]
cglyc_lj = cglyc_lj[:len(cglyc_lj)-59]
deglyc_c = deglyc_c[:len(deglyc_c)-59]
deglyc_lj = deglyc_lj[:len(deglyc_lj)-59]
glyc_c = glyc_c[:len(glyc_c)-59]
glyc_lj = glyc_lj[:len(glyc_lj)-59]
print ('---------------')
print (len (x))
#print(len (t1))
#print(len (t2))
print (len (MHC_c))
print (len (pep_c))
print (len (aglyc_c))
print (len (cglyc_c))
print (len (deglyc_c))
print (len (glyc_c))
print (len (MHC_lj))
print (len (pep_lj))
print (len (aglyc_lj))
print (len (cglyc_lj))
print (len (deglyc_lj))
print (len (glyc_lj))

iex = {'COM Distance':x,'TCR_MHC-Coulombic':MHC_c,'TCR_MHC-LennardJones':MHC_lj,
       'TCR_Peptide_Coulombic':pep_c,'TCR_Peptide_LennardJones':pep_lj,
      'MHC_Glycans_Coulombic':aglyc_c,'MHC_Glycans_LennardJones':aglyc_lj,
      'Peptide_Glycans_Coulombic':cglyc_c,'Peptide_Glycans_LennardJones':cglyc_lj,
      'TCR_Glycan_Coulombic':deglyc_c,'TCR_Glycan_LennardJones':deglyc_lj,
      'Glycan_Glycan_Coulombic':glyc_c,'Glycan_Glycan_LennardJones':glyc_lj}

df=pd.DataFrame(iex)
df.to_excel('/Users/zrollins/Documents/Documents/TCR_glyco/glyco/50/iex.xlsx')
df['MHC-Coulombic SMA']= df.iloc[:,1].rolling(window=100).mean()
df['MHC-LennardJones SMA']= df.iloc[:,2].rolling(window=100).mean()
ax = plt.gca()
df.plot(kind='line',x='COM Distance', y='MHC-Coulombic SMA', color='magenta', ax=ax)
df.plot(kind='line',x='COM Distance', y='MHC-LennardJones SMA', color='blue', ax=ax)
ax.set_ylabel('Interaction Energy (kJ/mol)')
ax.set_xlabel('COM Distance (nm)')
ax.legend(['Coulombic SMA','Lennard Jones SMA'])
ax.set_title('TCR-MHC Potential Mean Force (Glycosylated, 50 ns)')
plt.xlim((5.9,10.0))
plt.savefig('/Users/zrollins/Documents/Documents/TCR_glyco/glyco/50/iex_mhc.png')
plt.show()

df['MART1_Coulombic SMA']= df.iloc[:,3].rolling(window=100).mean()
df['MART1_LennardJones SMA']= df.iloc[:,4].rolling(window=100).mean()
ax = plt.gca()
df.plot(kind='line',x='COM Distance', y='MART1_Coulombic SMA', color='magenta', ax=ax)
df.plot(kind='line',x='COM Distance', y='MART1_LennardJones SMA', color='blue', ax=ax)
ax.set_ylabel('Interaction Energy (kJ/mol)')
ax.set_xlabel('COM Distance (nm)')
ax.legend(['Coulombic SMA','Lennard Jones SMA'])
ax.set_title('TCR-MART1 Potential Mean Force (Glycosylated, 50 ns)')
plt.xlim((5.9,7.5))
plt.savefig('/Users/zrollins/Documents/Documents/TCR_glyco/glyco/50/iex_pep.png')
plt.show()
# Out:
# 39815
# 39815
# 39821
# 39762
# 39821
# 39821
# 39821
# ---------------
# 39762
# 39762
# 39762
# 39762
# 39762
# 39762
# 39762
# 39762
# 39762
# 39762
# 39762
# 39762
# 39762

# %%
#100ns MART1

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

#Data Arrays

t, t1, t2, t3, t4, t5, t6 = [], [], [], [], [], [], []
x, x1 = [], []
pep_c = []
pep_lj = []
MHC_c = []
MHC_lj = []
aglyc_c = []
aglyc_lj = []
cglyc_c = []
cglyc_lj = []
deglyc_c = []
deglyc_lj = []
glyc_c = []
glyc_lj = []
#COM Distance vs Time

with open("/Users/zrollins/Documents/Documents/TCR_glyco/glyco/60/pullxcf.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            t1.append(float(cols[0]))
            x1.append(float(cols[1]))
x = x1[::10]

#TCR-MHC IE vs Time

with open("/Users/zrollins/Documents/Documents/TCR_glyco/glyco/60/ie_DEA.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 3:
            t.append(float(cols[0]))
            MHC_c.append(float(cols[1]))
            MHC_lj.append(float(cols[2]))
            
#TCR-peptide IE vs Time

with open("/Users/zrollins/Documents/Documents/TCR_glyco/glyco/60/ie_DEC.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 3:
            t2.append(float(cols[0]))
            pep_c.append(float(cols[1]))
            pep_lj.append(float(cols[2]))

#MHC-glyc IE vs Time

with open("/Users/zrollins/Documents/Documents/TCR_glyco/glyco/60/ie_Aglyc.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 3:
            t3.append(float(cols[0]))
            aglyc_c.append(float(cols[1]))
            aglyc_lj.append(float(cols[2]))

#Peptide-glyc IE vs Time

with open("/Users/zrollins/Documents/Documents/TCR_glyco/glyco/60/ie_Cglyc.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 3:
            t4.append(float(cols[0]))
            cglyc_c.append(float(cols[1]))
            cglyc_lj.append(float(cols[2]))
            
#TCR-glyc IE vs Time

with open("/Users/zrollins/Documents/Documents/TCR_glyco/glyco/60/ie_DEglyc.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 3:
            t5.append(float(cols[0]))
            deglyc_c.append(float(cols[1]))
            deglyc_lj.append(float(cols[2]))
            
#glyc-glyc IE vs Time

with open("/Users/zrollins/Documents/Documents/TCR_glyco/glyco/60/ie_glyc.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 3:
            t6.append(float(cols[0]))
            glyc_c.append(float(cols[1]))
            glyc_lj.append(float(cols[2]))
            
print (len (x))
#print(len (t1))
#print(len (t2))
print (len (MHC_c))
print (len (pep_c))
print (len (aglyc_c))
print (len (cglyc_c))
print (len (deglyc_c))
print (len (glyc_c))
#PLOT Hbonds vs COM Distance
x = x[:len(x)-40]
MHC_c = MHC_c[:len(MHC_c)-39]
MHC_lj = MHC_lj[:len(MHC_lj)-39]
pep_c = pep_c[:len(pep_c)-45]
pep_lj = pep_lj[:len(pep_lj)-45]
#aglyc_c = aglyc_c[:len(aglyc_c)-0]
#aglyc_lj = aglyc_lj[:len(aglyc_lj)-0]
cglyc_c = cglyc_c[:len(cglyc_c)-45]
cglyc_lj = cglyc_lj[:len(cglyc_lj)-45]
deglyc_c = deglyc_c[:len(deglyc_c)-45]
deglyc_lj = deglyc_lj[:len(deglyc_lj)-45]
glyc_c = glyc_c[:len(glyc_c)-45]
glyc_lj = glyc_lj[:len(glyc_lj)-45]
print ('---------------')
print (len (x))
#print(len (t1))
#print(len (t2))
print (len (MHC_c))
print (len (pep_c))
print (len (aglyc_c))
print (len (cglyc_c))
print (len (deglyc_c))
print (len (glyc_c))
print (len (MHC_lj))
print (len (pep_lj))
print (len (aglyc_lj))
print (len (cglyc_lj))
print (len (deglyc_lj))
print (len (glyc_lj))

iex = {'COM Distance':x,'TCR_MHC-Coulombic':MHC_c,'TCR_MHC-LennardJones':MHC_lj,
       'TCR_Peptide_Coulombic':pep_c,'TCR_Peptide_LennardJones':pep_lj,
      'MHC_Glycans_Coulombic':aglyc_c,'MHC_Glycans_LennardJones':aglyc_lj,
      'Peptide_Glycans_Coulombic':cglyc_c,'Peptide_Glycans_LennardJones':cglyc_lj,
      'TCR_Glycan_Coulombic':deglyc_c,'TCR_Glycan_LennardJones':deglyc_lj,
      'Glycan_Glycan_Coulombic':glyc_c,'Glycan_Glycan_LennardJones':glyc_lj}

df=pd.DataFrame(iex)
df.to_excel('/Users/zrollins/Documents/Documents/TCR_glyco/glyco/60/iex.xlsx')
df['MHC-Coulombic SMA']= df.iloc[:,1].rolling(window=100).mean()
df['MHC-LennardJones SMA']= df.iloc[:,2].rolling(window=100).mean()
ax = plt.gca()
df.plot(kind='line',x='COM Distance', y='MHC-Coulombic SMA', color='magenta', ax=ax)
df.plot(kind='line',x='COM Distance', y='MHC-LennardJones SMA', color='blue', ax=ax)
ax.set_ylabel('Interaction Energy (kJ/mol)')
ax.set_xlabel('COM Distance (nm)')
ax.legend(['Coulombic SMA','Lennard Jones SMA'])
ax.set_title('TCR-MHC Potential Mean Force (Glycosylated, 60 ns)')
plt.xlim((5.9,10.0))
plt.savefig('/Users/zrollins/Documents/Documents/TCR_glyco/glyco/60/iex_mhc.png')
plt.show()

df['MART1_Coulombic SMA']= df.iloc[:,3].rolling(window=100).mean()
df['MART1_LennardJones SMA']= df.iloc[:,4].rolling(window=100).mean()
ax = plt.gca()
df.plot(kind='line',x='COM Distance', y='MART1_Coulombic SMA', color='magenta', ax=ax)
df.plot(kind='line',x='COM Distance', y='MART1_LennardJones SMA', color='blue', ax=ax)
ax.set_ylabel('Interaction Energy (kJ/mol)')
ax.set_xlabel('COM Distance (nm)')
ax.legend(['Coulombic SMA','Lennard Jones SMA'])
ax.set_title('TCR-MART1 Potential Mean Force (Glycosylated, 60 ns)')
plt.xlim((5.9,7.5))
plt.savefig('/Users/zrollins/Documents/Documents/TCR_glyco/glyco/60/iex_pep.png')
plt.show()
# Out:
# 12872
# 12871
# 12877
# 12832
# 12877
# 12877
# 12877
# ---------------
# 12832
# 12832
# 12832
# 12832
# 12832
# 12832
# 12832
# 12832
# 12832
# 12832
# 12832
# 12832
# 12832

# %%
#100ns MART1

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

#Data Arrays

t, t1, t2, t3, t4, t5, t6 = [], [], [], [], [], [], []
x, x1 = [], []
pep_c = []
pep_lj = []
MHC_c = []
MHC_lj = []
aglyc_c = []
aglyc_lj = []
cglyc_c = []
cglyc_lj = []
deglyc_c = []
deglyc_lj = []
glyc_c = []
glyc_lj = []
#COM Distance vs Time

with open("/Users/zrollins/Documents/Documents/TCR_glyco/glyco/70/pullxcf.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            t1.append(float(cols[0]))
            x1.append(float(cols[1]))
x = x1[::1]

#TCR-MHC IE vs Time

with open("/Users/zrollins/Documents/Documents/TCR_glyco/glyco/70/ie_DEA.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 3:
            t.append(float(cols[0]))
            MHC_c.append(float(cols[1]))
            MHC_lj.append(float(cols[2]))
            
#TCR-peptide IE vs Time

with open("/Users/zrollins/Documents/Documents/TCR_glyco/glyco/70/ie_DEC.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 3:
            t2.append(float(cols[0]))
            pep_c.append(float(cols[1]))
            pep_lj.append(float(cols[2]))

#MHC-glyc IE vs Time

with open("/Users/zrollins/Documents/Documents/TCR_glyco/glyco/70/ie_Aglyc.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 3:
            t3.append(float(cols[0]))
            aglyc_c.append(float(cols[1]))
            aglyc_lj.append(float(cols[2]))

#Peptide-glyc IE vs Time

with open("/Users/zrollins/Documents/Documents/TCR_glyco/glyco/70/ie_Cglyc.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 3:
            t4.append(float(cols[0]))
            cglyc_c.append(float(cols[1]))
            cglyc_lj.append(float(cols[2]))
            
#TCR-glyc IE vs Time

with open("/Users/zrollins/Documents/Documents/TCR_glyco/glyco/70/ie_DEglyc.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 3:
            t5.append(float(cols[0]))
            deglyc_c.append(float(cols[1]))
            deglyc_lj.append(float(cols[2]))
            
#glyc-glyc IE vs Time

with open("/Users/zrollins/Documents/Documents/TCR_glyco/glyco/70/ie_glyc.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 3:
            t6.append(float(cols[0]))
            glyc_c.append(float(cols[1]))
            glyc_lj.append(float(cols[2]))
            
print (len (x))
#print(len (t1))
#print(len (t2))
print (len (MHC_c))
print (len (pep_c))
print (len (aglyc_c))
print (len (cglyc_c))
print (len (deglyc_c))
print (len (glyc_c))
#PLOT Hbonds vs COM Distance
x = x[:len(x)-37]
MHC_c = MHC_c[:len(MHC_c)-35]
MHC_lj = MHC_lj[:len(MHC_lj)-35]
pep_c = pep_c[:len(pep_c)-37]
pep_lj = pep_lj[:len(pep_lj)-37]
#aglyc_c = aglyc_c[:len(aglyc_c)-0]
#aglyc_lj = aglyc_lj[:len(aglyc_lj)-0]
cglyc_c = cglyc_c[:len(cglyc_c)-37]
cglyc_lj = cglyc_lj[:len(cglyc_lj)-37]
deglyc_c = deglyc_c[:len(deglyc_c)-37]
deglyc_lj = deglyc_lj[:len(deglyc_lj)-37]
glyc_c = glyc_c[:len(glyc_c)-37]
glyc_lj = glyc_lj[:len(glyc_lj)-37]
print ('---------------')
print (len (x))
#print(len (t1))
#print(len (t2))
print (len (MHC_c))
print (len (pep_c))
print (len (aglyc_c))
print (len (cglyc_c))
print (len (deglyc_c))
print (len (glyc_c))
print (len (MHC_lj))
print (len (pep_lj))
print (len (aglyc_lj))
print (len (cglyc_lj))
print (len (deglyc_lj))
print (len (glyc_lj))

iex = {'COM Distance':x,'TCR_MHC-Coulombic':MHC_c,'TCR_MHC-LennardJones':MHC_lj,
       'TCR_Peptide_Coulombic':pep_c,'TCR_Peptide_LennardJones':pep_lj,
      'MHC_Glycans_Coulombic':aglyc_c,'MHC_Glycans_LennardJones':aglyc_lj,
      'Peptide_Glycans_Coulombic':cglyc_c,'Peptide_Glycans_LennardJones':cglyc_lj,
      'TCR_Glycan_Coulombic':deglyc_c,'TCR_Glycan_LennardJones':deglyc_lj,
      'Glycan_Glycan_Coulombic':glyc_c,'Glycan_Glycan_LennardJones':glyc_lj}

df=pd.DataFrame(iex)
df.to_excel('/Users/zrollins/Documents/Documents/TCR_glyco/glyco/70/iex.xlsx')
df['MHC-Coulombic SMA']= df.iloc[:,1].rolling(window=100).mean()
df['MHC-LennardJones SMA']= df.iloc[:,2].rolling(window=100).mean()
ax = plt.gca()
df.plot(kind='line',x='COM Distance', y='MHC-Coulombic SMA', color='magenta', ax=ax)
df.plot(kind='line',x='COM Distance', y='MHC-LennardJones SMA', color='blue', ax=ax)
ax.set_ylabel('Interaction Energy (kJ/mol)')
ax.set_xlabel('COM Distance (nm)')
ax.legend(['Coulombic SMA','Lennard Jones SMA'])
ax.set_title('TCR-MHC Potential Mean Force (Glycosylated, 70 ns)')
plt.xlim((5.9,10.0))
plt.savefig('/Users/zrollins/Documents/Documents/TCR_glyco/glyco/70/iex_mhc.png')
plt.show()

df['MART1_Coulombic SMA']= df.iloc[:,3].rolling(window=100).mean()
df['MART1_LennardJones SMA']= df.iloc[:,4].rolling(window=100).mean()
ax = plt.gca()
df.plot(kind='line',x='COM Distance', y='MART1_Coulombic SMA', color='magenta', ax=ax)
df.plot(kind='line',x='COM Distance', y='MART1_LennardJones SMA', color='blue', ax=ax)
ax.set_ylabel('Interaction Energy (kJ/mol)')
ax.set_xlabel('COM Distance (nm)')
ax.legend(['Coulombic SMA','Lennard Jones SMA'])
ax.set_title('TCR-MART1 Potential Mean Force (Glycosylated, 70 ns)')
plt.xlim((5.9,7.5))
plt.savefig('/Users/zrollins/Documents/Documents/TCR_glyco/glyco/70/iex_pep.png')
plt.show()
# Out:
# 12139
# 12137
# 12139
# 12102
# 12139
# 12139
# 12139
# ---------------
# 12102
# 12102
# 12102
# 12102
# 12102
# 12102
# 12102
# 12102
# 12102
# 12102
# 12102
# 12102
# 12102
