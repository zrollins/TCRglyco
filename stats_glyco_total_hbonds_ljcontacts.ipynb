# %%
import numpy as np
import pandas as pd
import matplotlib.patches as mpatches
import matplotlib.pyplot as plt
import scipy.stats as stats
import matplotlib.pyplot as plt
from pingouin import pairwise_tukey
from pingouin import pairwise_tukey
from openpyxl import load_workbook

path=r'/Users/zrollins/Documents/Documents/TCR_glyco/Total_HBonds_Contacts_Stats_Para1.xlsx'
book = load_workbook(path)
writer=pd.ExcelWriter(path, engine = 'openpyxl')
writer.book=book


index=['>0','1','5','10','25','50']
indexc=['>0','1','5','10','25','50']

#Contacts MHC 
M1_100_c=[2523, 955, 464, 285, 107, 23]
M1_95_c=[1946, 892, 532, 352, 122, 25]
M1_90_c=[2915, 1304, 693, 442, 135, 24]

GVA_100_c=[4339, 1418, 807, 541, 259, 69]
GVA_95_c=[3054, 1194, 695, 473, 232, 75]
GVA_90_c=[3617, 1343, 741, 470, 209, 40]


occ={'MART1(100 ns)':M1_100_c, 'MART1 (95 ns)':M1_95_c,'MART1 (90 ns)':M1_90_c,'GVA (100 ns)':GVA_100_c,'GVA (95 ns)':GVA_95_c,'GVA (90 ns)':GVA_90_c}
df = pd.DataFrame(occ, index=indexc)

cols=['MART1(100 ns)','MART1 (95 ns)', 'MART1 (90 ns)']
df['MART1'] = df[cols].astype(float).mean(axis=1)
df['MART1 SEM'] = df[cols].astype(float).sem(axis=1)

cols2=['GVA (100 ns)','GVA (95 ns)','GVA (90 ns)']
df['GVA'] = df[cols2].astype(float).mean(axis=1)
df['GVA SEM'] = df[cols2].astype(float).sem(axis=1)




#Contacts Peptide
M1_100_i=[1446, 731, 465, 332, 150, 36]
M1_95_i=[691, 342, 183, 133, 55, 13]
M1_90_i=[922, 460, 223, 141, 29, 2]

GVA_100_i=[1532, 636, 396, 285, 109, 38]
GVA_95_i=[1117, 562, 334, 230, 106, 27]
GVA_90_i=[719, 316, 222, 148, 55, 11]


occ1={'MART1(100 ns)':M1_100_i, 'MART1 (95 ns)':M1_95_i,'MART1 (90 ns)':M1_90_i,'GVA (100 ns)':GVA_100_i,'GVA (95 ns)':GVA_95_i,'GVA (90 ns)':GVA_90_i}
df1 = pd.DataFrame(occ1, index=index)

cols=['MART1(100 ns)','MART1 (95 ns)', 'MART1 (90 ns)']
df1['MART1'] = df1[cols].astype(float).mean(axis=1)
df1['MART1 SEM'] = df1[cols].astype(float).sem(axis=1)

cols2=['GVA (100 ns)','GVA (95 ns)','GVA (90 ns)']
df1['GVA'] = df1[cols2].astype(float).mean(axis=1)
df1['GVA SEM'] = df1[cols2].astype(float).sem(axis=1)

#H-Bonds MHC
M1_100_cMHC=[33, 15, 4, 2, 1, 0]
M1_95_cMHC=[18, 11, 7, 7, 4, 0]
M1_90_cMHC=[32, 12, 6, 2, 2, 1]

GVA_100_cMHC=[71, 24, 13, 9, 7, 3]
GVA_95_cMHC=[42, 15, 12, 12, 6, 4]
GVA_90_cMHC=[48, 15, 13, 10, 5, 1]


occ2={'MART1(100 ns)':M1_100_cMHC, 'MART1 (95 ns)':M1_95_cMHC,'MART1 (90 ns)':M1_90_cMHC,'GVA (100 ns)':GVA_100_cMHC,'GVA (95 ns)':GVA_95_cMHC,'GVA (90 ns)':GVA_90_cMHC}
df2 = pd.DataFrame(occ2, index=indexc)

cols=['MART1(100 ns)','MART1 (95 ns)', 'MART1 (90 ns)']
df2['MART1'] = df2[cols].astype(float).mean(axis=1)
df2['MART1 SEM'] = df2[cols].astype(float).sem(axis=1)

cols2=['GVA (100 ns)','GVA (95 ns)','GVA (90 ns)']
df2['GVA'] = df2[cols2].astype(float).mean(axis=1)
df2['GVA SEM'] = df2[cols2].astype(float).sem(axis=1)


#H-Bonds Peptide
M1_100_cpep=[10, 7, 6, 4, 3, 1]
M1_95_cpep=[6, 3, 3, 3, 2, 1]
M1_90_cpep=[7, 3, 3, 2, 0, 0]

GVA_100_cpep=[9, 4, 4, 4, 3, 1]
GVA_95_cpep=[7, 4, 4, 3, 3, 1]
GVA_90_cpep=[5, 3, 3, 3, 1, 0]

occ3={'MART1(100 ns)':M1_100_cpep, 'MART1 (95 ns)':M1_95_cpep,'MART1 (90 ns)':M1_90_cpep,'GVA (100 ns)':GVA_100_cpep,'GVA (95 ns)':GVA_95_cpep,'GVA (90 ns)':GVA_90_cpep}
df3 = pd.DataFrame(occ3, index=indexc)

cols=['MART1(100 ns)','MART1 (95 ns)', 'MART1 (90 ns)']
df3['MART1'] = df3[cols].astype(float).mean(axis=1)
df3['MART1 SEM'] = df3[cols].astype(float).sem(axis=1)

cols2=['GVA (100 ns)','GVA (95 ns)','GVA (90 ns)']
df3['GVA'] = df3[cols2].astype(float).mean(axis=1)
df3['GVA SEM'] = df3[cols2].astype(float).sem(axis=1)

contacts = df + df1
hbonds = df2 + df3


#HBonds & Contacts: Statistics

##0% Cutoff Contacts
contacts0 = contacts.T.iloc[:,:1].reset_index(drop=True)
contacts0_M1 = contacts0.iloc[:3,:].reset_index(drop=True)
contacts0_GVA = contacts0.iloc[3:6,:].reset_index(drop=True)
c0 = pd.DataFrame()
C0 = {'>0 deglyco':contacts0_M1, '>0 glyco':contacts0_GVA}
c0 = pd.concat(C0,axis=1, ignore_index=True)
c0.columns = ['>0 deglyco', '>0 glyco']
###One-Way ANOVA
f, p = stats.kruskal(c0.dropna()['>0 deglyco'],c0.dropna()['>0 glyco'])
print('--------------------------------------------------')
print('One-Way ANOVA: >0% Contacts')
print('--------------------------------------------------')
print ('F=',f,',', 'PR(>F)=',p)

###Student's t-test
f, p = stats.ttest_ind(c0.dropna()['>0 deglyco'],c0.dropna()['>0 glyco'])
print('--------------------------------------------------')
print('Student t-test: MART1-GVA >0% Contacts')
print('--------------------------------------------------')
print ('F=',f,',', 'PR(>F)=',p)


###Posthoc Tukey-Kramer Test
tk=c0[['>0 deglyco','>0 glyco']].copy()
tk_melt=pd.melt(tk.reset_index(),id_vars=['index'], value_vars=['>0 deglyco','>0 glyco'])
tk_melt.columns=['index','Conditions','value']
tk_melt=tk_melt.dropna()
tk_melt=tk_melt.reset_index(drop=True)
m_comp=pairwise_tukey(data=tk_melt, dv='value', between ='Conditions')
m_comp.to_excel(writer,'Contacts0_Stats')
writer.save()

##1% Cutoff Contacts
contacts1 = contacts.T.iloc[:,1:2].reset_index(drop=True)
contacts1_M1 = contacts1.iloc[:3,:].reset_index(drop=True)
contacts1_GVA = contacts1.iloc[3:6,:].reset_index(drop=True)
c1 = pd.DataFrame()
C1 = {'>1 deglyco':contacts1_M1, '>1 glyco':contacts1_GVA}
c1 = pd.concat(C1,axis=1, ignore_index=True)
c1.columns = ['>1 deglyco', '>1 glyco']
###One-Way ANOVA
f, p = stats.kruskal(c1.dropna()['>1 deglyco'],c1.dropna()['>1 glyco'])
print('--------------------------------------------------')
print('One-Way ANOVA: >1% Contacts')
print('--------------------------------------------------')
print ('F=',f,',', 'PR(>F)=',p)

###Posthoc Tukey-Kramer Test
tk=c1[['>1 deglyco','>1 glyco']].copy()
tk_melt=pd.melt(tk.reset_index(),id_vars=['index'], value_vars=['>1 deglyco','>1 glyco'])
tk_melt.columns=['index','Conditions','value']
tk_melt=tk_melt.dropna()
tk_melt=tk_melt.reset_index(drop=True)
m_comp=pairwise_tukey(data=tk_melt, dv='value', between ='Conditions')
m_comp.to_excel(writer,'Contacts1_Stats')
writer.save()

##5% Cutoff Contacts
contacts5 = contacts.T.iloc[:,2:3].reset_index(drop=True)
contacts5_M1 = contacts5.iloc[:3,:].reset_index(drop=True)
contacts5_GVA = contacts5.iloc[3:6,:].reset_index(drop=True)
c5 = pd.DataFrame()
C5 = {'>5 deglyco':contacts5_M1, '>5 glyco':contacts5_GVA}
c5 = pd.concat(C5,axis=1, ignore_index=True)
c5.columns = ['>5 deglyco', '>5 glyco']
###One-Way ANOVA
f, p = stats.kruskal(c5.dropna()['>5 deglyco'],c5.dropna()['>5 glyco'])
print('--------------------------------------------------')
print('One-Way ANOVA: >5% Contacts')
print('--------------------------------------------------')
print ('F=',f,',', 'PR(>F)=',p)

###Posthoc Tukey-Kramer Test
tk=c5[['>5 deglyco','>5 glyco']].copy()
tk_melt=pd.melt(tk.reset_index(),id_vars=['index'], value_vars=['>5 deglyco','>5 glyco'])
tk_melt.columns=['index','Conditions','value']
tk_melt=tk_melt.dropna()
tk_melt=tk_melt.reset_index(drop=True)
m_comp=pairwise_tukey(data=tk_melt, dv='value', between ='Conditions')
m_comp.to_excel(writer,'Contacts5_Stats')
writer.save()

##10% Cutoff Contacts
contacts10 = contacts.T.iloc[:,3:4].reset_index(drop=True)
contacts10_M1 = contacts10.iloc[:3,:].reset_index(drop=True)
contacts10_GVA = contacts10.iloc[3:6,:].reset_index(drop=True)
c10 = pd.DataFrame()
C10 = {'>10 deglyco':contacts10_M1, '>10 glyco':contacts10_GVA}
c10 = pd.concat(C10,axis=1, ignore_index=True)
c10.columns = ['>10 deglyco', '>10 glyco']
###One-Way ANOVA
f, p = stats.kruskal(c10.dropna()['>10 deglyco'],c10.dropna()['>10 glyco'])
print('--------------------------------------------------')
print('One-Way ANOVA: >10% Contacts')
print('--------------------------------------------------')
print ('F=',f,',', 'PR(>F)=',p)

###Posthoc Tukey-Kramer Test
tk=c10[['>10 deglyco','>10 glyco']].copy()
tk_melt=pd.melt(tk.reset_index(),id_vars=['index'], value_vars=['>10 deglyco','>10 glyco'])
tk_melt.columns=['index','Conditions','value']
tk_melt=tk_melt.dropna()
tk_melt=tk_melt.reset_index(drop=True)
m_comp=pairwise_tukey(data=tk_melt, dv='value', between ='Conditions')
m_comp.to_excel(writer,'Contacts10_Stats')
writer.save()

##25% Cutoff Contacts
contacts25 = contacts.T.iloc[:,4:5].reset_index(drop=True)
contacts25_M1 = contacts25.iloc[:3,:].reset_index(drop=True)
contacts25_GVA = contacts25.iloc[3:6,:].reset_index(drop=True)
c25 = pd.DataFrame()
C25 = {'>25 deglyco':contacts25_M1, '>25 glyco':contacts25_GVA}
c25 = pd.concat(C25,axis=1, ignore_index=True)
c25.columns = ['>25 deglyco', '>25 glyco']
###One-Way ANOVA
f, p = stats.kruskal(c25.dropna()['>25 deglyco'],c25.dropna()['>25 glyco'])
print('--------------------------------------------------')
print('One-Way ANOVA: >25% Contacts')
print('--------------------------------------------------')
print ('F=',f,',', 'PR(>F)=',p)

###Posthoc Tukey-Kramer Test
tk=c25[['>25 deglyco','>25 glyco']].copy()
tk_melt=pd.melt(tk.reset_index(),id_vars=['index'], value_vars=['>25 deglyco','>25 glyco'])
tk_melt.columns=['index','Conditions','value']
tk_melt=tk_melt.dropna()
tk_melt=tk_melt.reset_index(drop=True)
m_comp=pairwise_tukey(data=tk_melt, dv='value', between ='Conditions')
m_comp.to_excel(writer,'Contacts25_Stats')
writer.save()

##50% Cutoff Contacts
contacts50 = contacts.T.iloc[:,4:5].reset_index(drop=True)
contacts50_M1 = contacts25.iloc[:3,:].reset_index(drop=True)
contacts50_GVA = contacts25.iloc[3:6,:].reset_index(drop=True)
c50 = pd.DataFrame()
C50 = {'>50 deglyco':contacts50_M1, '>50 glyco':contacts50_GVA}
c50 = pd.concat(C50,axis=1, ignore_index=True)
c50.columns = ['>50 deglyco', '>50 glyco']
###One-Way ANOVA
f, p = stats.kruskal(c50.dropna()['>50 deglyco'],c50.dropna()['>50 glyco'])
print('--------------------------------------------------')
print('One-Way ANOVA: >50% Contacts')
print('--------------------------------------------------')
print ('F=',f,',', 'PR(>F)=',p)

###Posthoc Tukey-Kramer Test
tk=c50[['>50 deglyco','>50 glyco']].copy()
tk_melt=pd.melt(tk.reset_index(),id_vars=['index'], value_vars=['>50 deglyco','>50 glyco'])
tk_melt.columns=['index','Conditions','value']
tk_melt=tk_melt.dropna()
tk_melt=tk_melt.reset_index(drop=True)
m_comp=pairwise_tukey(data=tk_melt, dv='value', between ='Conditions')
m_comp.to_excel(writer,'Contacts50_Stats')
writer.save()

##0% Cutoff HBonds
hbonds0 = hbonds.T.iloc[:,:1].reset_index(drop=True)
hbonds0_M1 = hbonds0.iloc[:3,:].reset_index(drop=True)
hbonds0_GVA = hbonds0.iloc[3:6,:].reset_index(drop=True)
c0 = pd.DataFrame()
C0 = {'>0 deglyco':hbonds0_M1, '>0 glyco':hbonds0_GVA}
c0 = pd.concat(C0,axis=1, ignore_index=True)
c0.columns = ['>0 deglyco', '>0 glyco']
###One-Way ANOVA
f, p = stats.kruskal(c0.dropna()['>0 deglyco'],c0.dropna()['>0 glyco'])
print('--------------------------------------------------')
print('One-Way ANOVA: >0% HBonds')
print('--------------------------------------------------')
print ('F=',f,',', 'PR(>F)=',p)

###Student's t-test

f, p = stats.ttest_ind(c0.dropna()['>0 deglyco'],c0.dropna()['>0 glyco'])
print('--------------------------------------------------')
print('Student t-test: MART1-GVA >0% HBonds')
print('--------------------------------------------------')
print ('F=',f,',', 'PR(>F)=',p)

###Posthoc Tukey-Kramer Test
tk=c0[['>0 deglyco','>0 glyco']].copy()
tk_melt=pd.melt(tk.reset_index(),id_vars=['index'], value_vars=['>0 deglyco','>0 glyco'])
tk_melt.columns=['index','Conditions','value']
tk_melt=tk_melt.dropna()
tk_melt=tk_melt.reset_index(drop=True)
m_comp=pairwise_tukey(data=tk_melt, dv='value', between ='Conditions')
m_comp.to_excel(writer,'HBonds0_Stats')
writer.save()

##1% Cutoff HBonds
hbonds1 = hbonds.T.iloc[:,1:2].reset_index(drop=True)
hbonds1_M1 = hbonds1.iloc[:3,:].reset_index(drop=True)
hbonds1_GVA = hbonds1.iloc[3:6,:].reset_index(drop=True)
c1 = pd.DataFrame()
C1 = {'>1 deglyco':hbonds1_M1, '>1 glyco':hbonds1_GVA}
c1 = pd.concat(C1,axis=1, ignore_index=True)
c1.columns = ['>1 deglyco', '>1 glyco']
###One-Way ANOVA
f, p = stats.kruskal(c1.dropna()['>1 deglyco'],c1.dropna()['>1 glyco'])
print('--------------------------------------------------')
print('One-Way ANOVA: >1% HBonds')
print('--------------------------------------------------')
print ('F=',f,',', 'PR(>F)=',p)

###Student's t-test
f, p = stats.ttest_ind(c1.dropna()['>1 deglyco'],c1.dropna()['>1 glyco'])
print('--------------------------------------------------')
print('Student t-test: MART1-GVA >1% HBonds')
print('--------------------------------------------------')
print ('F=',f,',', 'PR(>F)=',p)

###Posthoc Tukey-Kramer Test
tk=c1[['>1 deglyco','>1 glyco']].copy()
tk_melt=pd.melt(tk.reset_index(),id_vars=['index'], value_vars=['>1 deglyco','>1 glyco'])
tk_melt.columns=['index','Conditions','value']
tk_melt=tk_melt.dropna()
tk_melt=tk_melt.reset_index(drop=True)
m_comp=pairwise_tukey(data=tk_melt, dv='value', between ='Conditions')
m_comp.to_excel(writer,'HBonds1_Stats')
writer.save()

##5% Cutoff HBonds
hbonds5 = hbonds.T.iloc[:,2:3].reset_index(drop=True)
hbonds5_M1 = hbonds5.iloc[:3,:].reset_index(drop=True)
hbonds5_GVA = hbonds5.iloc[3:6,:].reset_index(drop=True)
c5 = pd.DataFrame()
C5 = {'>5 deglyco':hbonds5_M1, '>5 glyco':hbonds5_GVA}
c5 = pd.concat(C5,axis=1, ignore_index=True)
c5.columns = ['>5 deglyco', '>5 glyco']
###One-Way ANOVA
f, p = stats.kruskal(c5.dropna()['>5 deglyco'],c5.dropna()['>5 glyco'])
print('--------------------------------------------------')
print('One-Way ANOVA: >5% HBonds')
print('--------------------------------------------------')
print ('F=',f,',', 'PR(>F)=',p)

###Posthoc Tukey-Kramer Test
tk=c5[['>5 deglyco','>5 glyco']].copy()
tk_melt=pd.melt(tk.reset_index(),id_vars=['index'], value_vars=['>5 deglyco','>5 glyco'])
tk_melt.columns=['index','Conditions','value']
tk_melt=tk_melt.dropna()
tk_melt=tk_melt.reset_index(drop=True)
m_comp=pairwise_tukey(data=tk_melt, dv='value', between ='Conditions')
m_comp.to_excel(writer,'HBonds5_Stats')
writer.save()

##10% Cutoff HBonds
hbonds10 = hbonds.T.iloc[:,3:4].reset_index(drop=True)
hbonds10_M1 = hbonds10.iloc[:3,:].reset_index(drop=True)
hbonds10_GVA = hbonds10.iloc[3:6,:].reset_index(drop=True)
c10 = pd.DataFrame()
C10 = {'>10 deglyco':hbonds10_M1, '>10 glyco':hbonds10_GVA}
c10 = pd.concat(C10,axis=1, ignore_index=True)
c10.columns = ['>10 deglyco', '>10 glyco']
###One-Way ANOVA
f, p = stats.kruskal(c10.dropna()['>10 deglyco'],c10.dropna()['>10 glyco'])
print('--------------------------------------------------')
print('One-Way ANOVA: >10% HBonds')
print('--------------------------------------------------')
print ('F=',f,',', 'PR(>F)=',p)

###Posthoc Tukey-Kramer Test
tk=c10[['>10 deglyco','>10 glyco']].copy()
tk_melt=pd.melt(tk.reset_index(),id_vars=['index'], value_vars=['>10 deglyco','>10 glyco'])
tk_melt.columns=['index','Conditions','value']
tk_melt=tk_melt.dropna()
tk_melt=tk_melt.reset_index(drop=True)
m_comp=pairwise_tukey(data=tk_melt, dv='value', between ='Conditions')
m_comp.to_excel(writer,'HBonds10_Stats')
writer.save()

##25% Cutoff HBonds
hbonds25 = hbonds.T.iloc[:,4:5].reset_index(drop=True)
hbonds25_M1 = hbonds25.iloc[:3,:].reset_index(drop=True)
hbonds25_GVA = hbonds25.iloc[3:6,:].reset_index(drop=True)
c25 = pd.DataFrame()
C25 = {'>25 deglyco':hbonds25_M1, '>25 glyco':hbonds25_GVA}
c25 = pd.concat(C25,axis=1, ignore_index=True)
c25.columns = ['>25 deglyco', '>25 glyco']
###One-Way ANOVA
f, p = stats.kruskal(c25.dropna()['>25 deglyco'],c25.dropna()['>25 glyco'])
print('--------------------------------------------------')
print('One-Way ANOVA: >25% HBonds')
print('--------------------------------------------------')
print ('F=',f,',', 'PR(>F)=',p)

###Posthoc Tukey-Kramer Test
tk=c25[['>25 deglyco','>25 glyco']].copy()
tk_melt=pd.melt(tk.reset_index(),id_vars=['index'], value_vars=['>25 deglyco','>25 glyco'])
tk_melt.columns=['index','Conditions','value']
tk_melt=tk_melt.dropna()
tk_melt=tk_melt.reset_index(drop=True)
m_comp=pairwise_tukey(data=tk_melt, dv='value', between ='Conditions')
m_comp.to_excel(writer,'HBonds25_Stats')

##50% Cutoff HBonds
hbonds50 = hbonds.T.iloc[:,4:5].reset_index(drop=True)
hbonds50_M1 = hbonds50.iloc[:3,:].reset_index(drop=True)
hbonds50_GVA = hbonds50.iloc[3:6,:].reset_index(drop=True)
c50 = pd.DataFrame()
C50 = {'>50 deglyco':hbonds50_M1, '>50 glyco':hbonds50_GVA}
c50 = pd.concat(C50,axis=1, ignore_index=True)
c50.columns = ['>50 deglyco', '>50 glyco']
###One-Way ANOVA
f, p = stats.kruskal(c50.dropna()['>50 deglyco'],c50.dropna()['>50 glyco'])
print('--------------------------------------------------')
print('One-Way ANOVA: >50% HBonds')
print('--------------------------------------------------')
print ('F=',f,',', 'PR(>F)=',p)

###Posthoc Tukey-Kramer Test
tk=c50[['>50 deglyco','>50 glyco']].copy()
tk_melt=pd.melt(tk.reset_index(),id_vars=['index'], value_vars=['>50 deglyco','>50 glyco'])
tk_melt.columns=['index','Conditions','value']
tk_melt=tk_melt.dropna()
tk_melt=tk_melt.reset_index(drop=True)
m_comp=pairwise_tukey(data=tk_melt, dv='value', between ='Conditions')
m_comp.to_excel(writer,'HBonds50_Stats')
writer.save()
# Out:
# --------------------------------------------------
# One-Way ANOVA: >0% Contacts
# --------------------------------------------------
# F= 3.857142857142854 , PR(>F)= 0.049534613435626915
# --------------------------------------------------
# Student t-test: MART1-GVA >0% Contacts
# --------------------------------------------------
# F= -1.9081832243359742 , PR(>F)= 0.12901576553686073
# --------------------------------------------------
# One-Way ANOVA: >1% Contacts
# --------------------------------------------------
# F= 0.42857142857142705 , PR(>F)= 0.5126907602619241
# --------------------------------------------------
# One-Way ANOVA: >5% Contacts
# --------------------------------------------------
# F= 3.857142857142854 , PR(>F)= 0.049534613435626915
# --------------------------------------------------
# One-Way ANOVA: >10% Contacts
# --------------------------------------------------
# F= 3.857142857142854 , PR(>F)= 0.049534613435626915
# ...
