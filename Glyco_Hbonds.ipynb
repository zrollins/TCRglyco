# %%
#50 ns

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

#Position vs Time
x1, t1 = [], []

with open("/Users/zrollins/Documents/Documents/TCR_glyco/glyco/50/pullxcf.xvg") as f:
    #lines = (line for line in f if not line.startsiwith('#') if not line.startswith('$'))
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            t1.append(float(cols[0]))
            x1.append(float(cols[1]))
x = x1[::10]

#TCR-MHC H_Number vs Time

t, ha, haa = [], [], []

with open("/Users/zrollins/Documents/Documents/TCR_glyco/glyco/50/num_interface_TCR_MHC.xvg") as f:
    #lines = (line for line in f if not line.startsiwith('#') if not line.startswith('$'))
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 3:
            t.append(float(cols[0]))
            ha.append(float(cols[1]))
            haa.append(float(cols[2]))



#TCR-peptide H_Number vs Time

t, hc, hcc = [], [], []

with open("/Users/zrollins/Documents/Documents/TCR_glyco/glyco/50/num_interface_TCR_pep.xvg") as f:
    #lines = (line for line in f if not line.startsiwith('#') if not line.startswith('$'))
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 3:
            t.append(float(cols[0]))
            hc.append(float(cols[1]))
            hcc.append(float(cols[2]))
            
#TCR-peptide H_Number vs Time

t, hb, hbb = [], [], []

with open("/Users/zrollins/Documents/Documents/TCR_glyco/glyco/50/num_interface_TCR_glyc.xvg") as f:
    #lines = (line for line in f if not line.startsiwith('#') if not line.startswith('$'))
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 3:
            t.append(float(cols[0]))
            hb.append(float(cols[1]))
            hbb.append(float(cols[2]))
            
#TCR-peptide H_Number vs Time

t, hd, hdd = [], [], []

with open("/Users/zrollins/Documents/Documents/TCR_glyco/glyco/50/num_interface_MHC_glyc.xvg") as f:
    #lines = (line for line in f if not line.startsiwith('#') if not line.startswith('$'))
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 3:
            t.append(float(cols[0]))
            hd.append(float(cols[1]))
            hdd.append(float(cols[2]))            
#TCR-peptide H_Number vs Time

t, he, hee = [], [], []

with open("/Users/zrollins/Documents/Documents/TCR_glyco/glyco/50/num_interface_pep_glyc.xvg") as f:
    #lines = (line for line in f if not line.startsiwith('#') if not line.startswith('$'))
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 3:
            t.append(float(cols[0]))
            he.append(float(cols[1]))
            hee.append(float(cols[2]))            
                        
#TCR-peptide H_Number vs Time

t, hf, hff = [], [], []

with open("/Users/zrollins/Documents/Documents/TCR_glyco/glyco/50/num_interface_glyc_glyc.xvg") as f:
    #lines = (line for line in f if not line.startsiwith('#') if not line.startswith('$'))
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 3:
            t.append(float(cols[0]))
            hf.append(float(cols[1]))
            hff.append(float(cols[2]))            
                        
#PLOT Hbonds vs Time

hbonds = {'Time (ps)': t,'TCR_MART1':hc,'TCR_MHC':ha,'TCR_Glycans':hb,'MHC_Glycans':hd,'MART1_Glycans':he,'Glycan_Glycan':hf}
df = pd.DataFrame(hbonds)
df['TCR_MART1 SMA']= df.iloc[:,1].rolling(window=200).mean()
df['TCR_MHC SMA']= df.iloc[:,2].rolling(window=200).mean()
df['TCR_Glycans SMA']= df.iloc[:,3].rolling(window=200).mean()
df['MHC_Glycans SMA']= df.iloc[:,4].rolling(window=200).mean()
df['MART1_Glycans SMA']= df.iloc[:,5].rolling(window=200).mean()
df['Glycan_Glycan SMA']= df.iloc[:,6].rolling(window=200).mean()
ax = plt.gca()
df.plot(kind='line',x='Time (ps)', y='TCR_MART1 SMA', color='magenta', ax=ax)
df.plot(kind='line',x='Time (ps)', y='TCR_MHC SMA', color= 'blue', ax=ax)
df.plot(kind='line',x='Time (ps)', y='TCR_Glycans SMA', color= 'black', ax=ax)
df.plot(kind='line',x='Time (ps)', y='MHC_Glycans SMA', color= 'red', ax=ax)
df.plot(kind='line',x='Time (ps)', y='MART1_Glycans SMA', color= 'orange', ax=ax)
df.plot(kind='line',x='Time (ps)', y='Glycan_Glycan SMA', color= 'green', ax=ax)
ax.set_ylabel('Number of Hyrogen Bonds')
ax.set_title('H-Bonds vs Time (50 ns Configuration)')
plt.savefig('/Users/zrollins/Documents/Documents/TCR_glyco/glyco/50/HT_70ns.png')
plt.show()


#PLOT Hbonds vs COM Distance
print (len(ha))
print (len(x))
ha1 = ha[:len(ha)-6]
hc1 = hc[:len(hc)-6]
hb1 = hb[:len(hb)-6]
hd1 = hd[:len(hd)-6]
he1 = he[:len(he)-6]
hf1 = hf[:len(hf)-6]

hbonds2 = {'COM Distance (nm)':x, 'TCR_MART1':hc1,'TCR_MHC':ha1,'TCR_Glycans':hb1,'MHC_Glycans':hd1,'MART1_Glycans':he1,'Glycan_Glycan':hf1}
df2 = pd.DataFrame(hbonds2)
df2.to_excel('/Users/zrollins/Documents/Documents/TCR_glyco/glyco/50/hx.xlsx')
df2['Peptide']= df.iloc[:,1].rolling(window=1).mean()
df2['MHC']= df.iloc[:,2].rolling(window=1).mean()
ax = plt.gca()
df2.plot(kind='line',x='COM Distance (nm)', y='TCR_MART1', color='magenta', ax=ax)
df2.plot(kind='line',x='COM Distance (nm)', y='TCR_MHC', color= 'blue', ax=ax)
df2.plot(kind='line',x='COM Distance (nm)', y='TCR_Glycans', color= 'black', ax=ax)
df2.plot(kind='line',x='COM Distance (nm)', y='MHC_Glycans', color= 'red', ax=ax)
df2.plot(kind='line',x='COM Distance (nm)', y='MART1_Glycans', color= 'orange', ax=ax)
df2.plot(kind='line',x='COM Distance (nm)', y='Glycan_Glycan', color= 'green', ax=ax)
ax.set_xlim(6,7.5)
ax.set_ylabel('Number of Hyrogen Bonds')
ax.set_title('H-Bonds vs Distance (50 ns Configuration)')
plt.savefig('/Users/zrollins/Documents/Documents/TCR_glyco/glyco/50/HX.png')
plt.show()

#Plot Separation Velocity vs Time
vel = []
vel = np.gradient(x1)
acc = []
acc = np.gradient(vel)
v = {'Time (ps)':t1, 'COM Distance (nm)':x1, 'Instantaneous Velocity':vel, 'Instant Acceleration':acc}
df3 = pd.DataFrame(v)
df3['Instantaneous Velocity SMA']= df3.iloc[:,2].rolling(window=1000).mean()
ax = plt.gca()
df3.plot(kind='line',x='Time (ps)', y='Instantaneous Velocity SMA', color='black', ax=ax)
ax.set_ylabel('Velocity (nm/ps)')
ax.set_title('Separation Velocity (50 ns Configuration)')
plt.savefig('/Users/zrollins/Documents/Documents/TCR_glyco/glyco/50/Vel.png')
plt.show()

#Plot H-Bond Frequency
    #Find max_v, max_t
max_v= 0.0010
df4 = df3.loc[df3['Instantaneous Velocity SMA'] >= max_v]
max_t=df4.values[0,0]
    #Partition H-Bonds & Time
df5 = df.drop(df[df['Time (ps)'] >= max_t].index)
h_tot = df5['TCR_MHC']+ df5['TCR_MART1'] + df5['TCR_Glycans'] + df5['MHC_Glycans'] + df5['MART1_Glycans'] +df5['Glycan_Glycan']
df5['Total_Hs'] = h_tot
df8 = df5.groupby('Total_Hs')['Time (ps)'].size().reset_index(name='Total Time (ps)')
df8['H-Bond Frequency (pMHC)']= df8['Total Time (ps)']/max_t
df8.to_excel('/Users/zrollins/Documents/Documents/TCR_glyco/glyco/50/hfrequency.xlsx')
print (df8)

    # Plot Number
    
    # Plot Frequency
# Out:
# 39821
# 39815
#     Total_Hs  Total Time (ps)  H-Bond Frequency (pMHC)
# 0        0.0             1034                 0.026230
# 1        1.0              772                 0.019584
# 2        2.0              894                 0.022679
# 3        3.0             1157                 0.029350
# 4        4.0             2590                 0.065702
# 5        5.0             5308                 0.134651
# 6        6.0             7598                 0.192742
# 7        7.0             8163                 0.207075
# 8        8.0             6404                 0.162454
# 9        9.0             3732                 0.094672
# 10      10.0             1365                 0.034627
# 11      11.0              329                 0.008346
# 12      12.0               63                 0.001598
# 13      13.0               11                 0.000279
# 14      14.0                1                 0.000025

# %%
#60 ns

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

#Position vs Time
x1, t1 = [], []

with open("/Users/zrollins/Documents/Documents/TCR_glyco/glyco/60/pullxcf.xvg") as f:
    #lines = (line for line in f if not line.startsiwith('#') if not line.startswith('$'))
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            t1.append(float(cols[0]))
            x1.append(float(cols[1]))
x = x1[::10]

#TCR-MHC H_Number vs Time

t, ha, haa = [], [], []

with open("/Users/zrollins/Documents/Documents/TCR_glyco/glyco/60/num_interface_TCR_MHC.xvg") as f:
    #lines = (line for line in f if not line.startsiwith('#') if not line.startswith('$'))
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 3:
            t.append(float(cols[0]))
            ha.append(float(cols[1]))
            haa.append(float(cols[2]))



#TCR-peptide H_Number vs Time

t, hc, hcc = [], [], []

with open("/Users/zrollins/Documents/Documents/TCR_glyco/glyco/60/num_interface_TCR_pep.xvg") as f:
    #lines = (line for line in f if not line.startsiwith('#') if not line.startswith('$'))
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 3:
            t.append(float(cols[0]))
            hc.append(float(cols[1]))
            hcc.append(float(cols[2]))
            
#TCR-peptide H_Number vs Time

t, hb, hbb = [], [], []

with open("/Users/zrollins/Documents/Documents/TCR_glyco/glyco/60/num_interface_TCR_glyc.xvg") as f:
    #lines = (line for line in f if not line.startsiwith('#') if not line.startswith('$'))
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 3:
            t.append(float(cols[0]))
            hb.append(float(cols[1]))
            hbb.append(float(cols[2]))
            
#TCR-peptide H_Number vs Time

t, hd, hdd = [], [], []

with open("/Users/zrollins/Documents/Documents/TCR_glyco/glyco/60/num_interface_MHC_glyc.xvg") as f:
    #lines = (line for line in f if not line.startsiwith('#') if not line.startswith('$'))
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 3:
            t.append(float(cols[0]))
            hd.append(float(cols[1]))
            hdd.append(float(cols[2]))            
#TCR-peptide H_Number vs Time

t, he, hee = [], [], []

with open("/Users/zrollins/Documents/Documents/TCR_glyco/glyco/60/num_interface_pep_glyc.xvg") as f:
    #lines = (line for line in f if not line.startsiwith('#') if not line.startswith('$'))
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 3:
            t.append(float(cols[0]))
            he.append(float(cols[1]))
            hee.append(float(cols[2]))            
                        
#TCR-peptide H_Number vs Time

t, hf, hff = [], [], []

with open("/Users/zrollins/Documents/Documents/TCR_glyco/glyco/60/num_interface_glyc_glyc.xvg") as f:
    #lines = (line for line in f if not line.startsiwith('#') if not line.startswith('$'))
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 3:
            t.append(float(cols[0]))
            hf.append(float(cols[1]))
            hff.append(float(cols[2]))            
                        
#PLOT Hbonds vs Time

hbonds = {'Time (ps)': t,'TCR_MART1':hc,'TCR_MHC':ha,'TCR_Glycans':hb,'MHC_Glycans':hd,'MART1_Glycans':he,'Glycan_Glycan':hf}
df = pd.DataFrame(hbonds)
df['TCR_MART1 SMA']= df.iloc[:,1].rolling(window=200).mean()
df['TCR_MHC SMA']= df.iloc[:,2].rolling(window=200).mean()
df['TCR_Glycans SMA']= df.iloc[:,3].rolling(window=200).mean()
df['MHC_Glycans SMA']= df.iloc[:,4].rolling(window=200).mean()
df['MART1_Glycans SMA']= df.iloc[:,5].rolling(window=200).mean()
df['Glycan_Glycan SMA']= df.iloc[:,6].rolling(window=200).mean()
ax = plt.gca()
df.plot(kind='line',x='Time (ps)', y='TCR_MART1 SMA', color='magenta', ax=ax)
df.plot(kind='line',x='Time (ps)', y='TCR_MHC SMA', color= 'blue', ax=ax)
df.plot(kind='line',x='Time (ps)', y='TCR_Glycans SMA', color= 'black', ax=ax)
df.plot(kind='line',x='Time (ps)', y='MHC_Glycans SMA', color= 'red', ax=ax)
df.plot(kind='line',x='Time (ps)', y='MART1_Glycans SMA', color= 'orange', ax=ax)
df.plot(kind='line',x='Time (ps)', y='Glycan_Glycan SMA', color= 'green', ax=ax)
ax.set_ylabel('Number of Hyrogen Bonds')
ax.set_title('H-Bonds vs Time (60 ns Configuration)')
plt.savefig('/Users/zrollins/Documents/Documents/TCR_glyco/glyco/60/HT_70ns.png')
plt.show()


#PLOT Hbonds vs COM Distance
print (len(ha))
print (len(x))
ha1 = ha[:len(ha)-5]
hc1 = hc[:len(hc)-5]
hb1 = hb[:len(hb)-5]
hd1 = hd[:len(hd)-5]
he1 = he[:len(he)-5]
hf1 = hf[:len(hf)-5]

hbonds2 = {'COM Distance (nm)':x, 'TCR_MART1':hc1,'TCR_MHC':ha1,'TCR_Glycans':hb1,'MHC_Glycans':hd1,'MART1_Glycans':he1,'Glycan_Glycan':hf1}
df2 = pd.DataFrame(hbonds2)
df2.to_excel('/Users/zrollins/Documents/Documents/TCR_glyco/glyco/60/hx.xlsx')
df2['Peptide']= df.iloc[:,1].rolling(window=1).mean()
df2['MHC']= df.iloc[:,2].rolling(window=1).mean()
ax = plt.gca()
df2.plot(kind='line',x='COM Distance (nm)', y='TCR_MART1', color='magenta', ax=ax)
df2.plot(kind='line',x='COM Distance (nm)', y='TCR_MHC', color= 'blue', ax=ax)
df2.plot(kind='line',x='COM Distance (nm)', y='TCR_Glycans', color= 'black', ax=ax)
df2.plot(kind='line',x='COM Distance (nm)', y='MHC_Glycans', color= 'red', ax=ax)
df2.plot(kind='line',x='COM Distance (nm)', y='MART1_Glycans', color= 'orange', ax=ax)
df2.plot(kind='line',x='COM Distance (nm)', y='Glycan_Glycan', color= 'green', ax=ax)
ax.set_xlim(6,7.5)
ax.set_ylabel('Number of Hyrogen Bonds')
ax.set_title('H-Bonds vs Distance (60 ns Configuration)')
plt.savefig('/Users/zrollins/Documents/Documents/TCR_glyco/glyco/60/HX.png')
plt.show()

#Plot Separation Velocity vs Time
vel = []
vel = np.gradient(x1)
acc = []
acc = np.gradient(vel)
v = {'Time (ps)':t1, 'COM Distance (nm)':x1, 'Instantaneous Velocity':vel, 'Instant Acceleration':acc}
df3 = pd.DataFrame(v)
df3['Instantaneous Velocity SMA']= df3.iloc[:,2].rolling(window=1000).mean()
ax = plt.gca()
df3.plot(kind='line',x='Time (ps)', y='Instantaneous Velocity SMA', color='black', ax=ax)
ax.set_ylabel('Velocity (nm/ps)')
ax.set_title('Separation Velocity (60 ns Configuration)')
plt.savefig('/Users/zrollins/Documents/Documents/TCR_glyco/glyco/60/Vel.png')
plt.show()

#Plot H-Bond Frequency
    #Find max_v, max_t
max_v= 0.0010
df4 = df3.loc[df3['Instantaneous Velocity SMA'] >= max_v]
max_t=df4.values[0,0]
    #Partition H-Bonds & Time
df5 = df.drop(df[df['Time (ps)'] >= max_t].index)
h_tot = df5['TCR_MHC']+ df5['TCR_MART1'] + df5['TCR_Glycans'] + df5['MHC_Glycans'] + df5['MART1_Glycans'] +df5['Glycan_Glycan']
df5['Total_Hs'] = h_tot
df8 = df5.groupby('Total_Hs')['Time (ps)'].size().reset_index(name='Total Time (ps)')
df8['H-Bond Frequency (pMHC)']= df8['Total Time (ps)']/max_t
df8.to_excel('/Users/zrollins/Documents/Documents/TCR_glyco/glyco/60/hfrequency.xlsx')
print (df8)
# Out:
# 12877
# 12872
#     Total_Hs  Total Time (ps)  H-Bond Frequency (pMHC)
# 0        0.0             1346                 0.104715
# 1        1.0              174                 0.013537
# 2        2.0              497                 0.038665
# 3        3.0              390                 0.030341
# 4        4.0              655                 0.050957
# 5        5.0             1239                 0.096391
# 6        6.0             1823                 0.141825
# 7        7.0             2168                 0.168665
# 8        8.0             1999                 0.155517
# 9        9.0             1454                 0.113117
# 10      10.0              772                 0.060060
# 11      11.0              267                 0.020772
# 12      12.0               61                 0.004746
# 13      13.0                8                 0.000622
# 14      14.0                1                 0.000078

# %%
#100 ns

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

#Position vs Time
x1, t1 = [], []

with open("/Users/zrollins/Documents/Documents/TCR_glyco/glyco/70/pullxcf.xvg") as f:
    #lines = (line for line in f if not line.startsiwith('#') if not line.startswith('$'))
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            t1.append(float(cols[0]))
            x1.append(float(cols[1]))
x = x1[::1]

#TCR-MHC H_Number vs Time

t, ha, haa = [], [], []

with open("/Users/zrollins/Documents/Documents/TCR_glyco/glyco/70/num_interface_TCR_MHC.xvg") as f:
    #lines = (line for line in f if not line.startsiwith('#') if not line.startswith('$'))
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 3:
            t.append(float(cols[0]))
            ha.append(float(cols[1]))
            haa.append(float(cols[2]))



#TCR-peptide H_Number vs Time

t, hc, hcc = [], [], []

with open("/Users/zrollins/Documents/Documents/TCR_glyco/glyco/70/num_interface_TCR_pep.xvg") as f:
    #lines = (line for line in f if not line.startsiwith('#') if not line.startswith('$'))
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 3:
            t.append(float(cols[0]))
            hc.append(float(cols[1]))
            hcc.append(float(cols[2]))
            
#TCR-peptide H_Number vs Time

t, hb, hbb = [], [], []

with open("/Users/zrollins/Documents/Documents/TCR_glyco/glyco/70/num_interface_TCR_glyc.xvg") as f:
    #lines = (line for line in f if not line.startsiwith('#') if not line.startswith('$'))
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 3:
            t.append(float(cols[0]))
            hb.append(float(cols[1]))
            hbb.append(float(cols[2]))
            
#TCR-peptide H_Number vs Time

t, hd, hdd = [], [], []

with open("/Users/zrollins/Documents/Documents/TCR_glyco/glyco/70/num_interface_MHC_glyc.xvg") as f:
    #lines = (line for line in f if not line.startsiwith('#') if not line.startswith('$'))
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 3:
            t.append(float(cols[0]))
            hd.append(float(cols[1]))
            hdd.append(float(cols[2]))            
#TCR-peptide H_Number vs Time

t, he, hee = [], [], []

with open("/Users/zrollins/Documents/Documents/TCR_glyco/glyco/70/num_interface_pep_glyc.xvg") as f:
    #lines = (line for line in f if not line.startsiwith('#') if not line.startswith('$'))
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 3:
            t.append(float(cols[0]))
            he.append(float(cols[1]))
            hee.append(float(cols[2]))            
                        
#TCR-peptide H_Number vs Time

t, hf, hff = [], [], []

with open("/Users/zrollins/Documents/Documents/TCR_glyco/glyco/70/num_interface_glyc_glyc.xvg") as f:
    #lines = (line for line in f if not line.startsiwith('#') if not line.startswith('$'))
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 3:
            t.append(float(cols[0]))
            hf.append(float(cols[1]))
            hff.append(float(cols[2]))            
                        
#PLOT Hbonds vs Time

hbonds = {'Time (ps)': t,'TCR_MART1':hc,'TCR_MHC':ha,'TCR_Glycans':hb,'MHC_Glycans':hd,'MART1_Glycans':he,'Glycan_Glycan':hf}
df = pd.DataFrame(hbonds)
df['TCR_MART1 SMA']= df.iloc[:,1].rolling(window=200).mean()
df['TCR_MHC SMA']= df.iloc[:,2].rolling(window=200).mean()
df['TCR_Glycans SMA']= df.iloc[:,3].rolling(window=200).mean()
df['MHC_Glycans SMA']= df.iloc[:,4].rolling(window=200).mean()
df['MART1_Glycans SMA']= df.iloc[:,5].rolling(window=200).mean()
df['Glycan_Glycan SMA']= df.iloc[:,6].rolling(window=200).mean()
ax = plt.gca()
df.plot(kind='line',x='Time (ps)', y='TCR_MART1 SMA', color='magenta', ax=ax)
df.plot(kind='line',x='Time (ps)', y='TCR_MHC SMA', color= 'blue', ax=ax)
df.plot(kind='line',x='Time (ps)', y='TCR_Glycans SMA', color= 'black', ax=ax)
df.plot(kind='line',x='Time (ps)', y='MHC_Glycans SMA', color= 'red', ax=ax)
df.plot(kind='line',x='Time (ps)', y='MART1_Glycans SMA', color= 'orange', ax=ax)
df.plot(kind='line',x='Time (ps)', y='Glycan_Glycan SMA', color= 'green', ax=ax)
ax.set_ylabel('Number of Hyrogen Bonds')
ax.set_title('H-Bonds vs Time (70 ns Configuration)')
plt.savefig('/Users/zrollins/Documents/Documents/TCR_glyco/glyco/70/HT.png')
plt.show()


#PLOT Hbonds vs COM Distance
print (len(ha))
print (len(x))
ha1 = ha[:len(ha)-0]
hc1 = hc[:len(hc)-0]
hb1 = hb[:len(hb)-0]
hd1 = hd[:len(hd)-0]
he1 = he[:len(he)-0]
hf1 = hf[:len(hf)-0]

hbonds2 = {'COM Distance (nm)':x, 'TCR_MART1':hc1,'TCR_MHC':ha1,'TCR_Glycans':hb1,'MHC_Glycans':hd1,'MART1_Glycans':he1,'Glycan_Glycan':hf1}
df2 = pd.DataFrame(hbonds2)
df2.to_excel('/Users/zrollins/Documents/Documents/TCR_glyco/glyco/70/hx.xlsx')
df2['Peptide']= df.iloc[:,1].rolling(window=1).mean()
df2['MHC']= df.iloc[:,2].rolling(window=1).mean()
ax = plt.gca()
df2.plot(kind='line',x='COM Distance (nm)', y='TCR_MART1', color='magenta', ax=ax)
df2.plot(kind='line',x='COM Distance (nm)', y='TCR_MHC', color= 'blue', ax=ax)
df2.plot(kind='line',x='COM Distance (nm)', y='TCR_Glycans', color= 'black', ax=ax)
df2.plot(kind='line',x='COM Distance (nm)', y='MHC_Glycans', color= 'red', ax=ax)
df2.plot(kind='line',x='COM Distance (nm)', y='MART1_Glycans', color= 'orange', ax=ax)
df2.plot(kind='line',x='COM Distance (nm)', y='Glycan_Glycan', color= 'green', ax=ax)
ax.set_xlim(6,7.5)
ax.set_ylabel('Number of Hyrogen Bonds')
ax.set_title('H-Bonds vs Distance (70 ns Configuration)')
plt.savefig('/Users/zrollins/Documents/Documents/TCR_glyco/glyco/70/HX.png')
plt.show()

#Plot Separation Velocity vs Time
vel = []
vel = np.gradient(x1)
acc = []
acc = np.gradient(vel)
v = {'Time (ps)':t1, 'COM Distance (nm)':x1, 'Instantaneous Velocity':vel, 'Instant Acceleration':acc}
df3 = pd.DataFrame(v)
df3['Instantaneous Velocity SMA']= df3.iloc[:,2].rolling(window=1000).mean()
ax = plt.gca()
df3.plot(kind='line',x='Time (ps)', y='Instantaneous Velocity SMA', color='black', ax=ax)
ax.set_ylabel('Velocity (nm/ps)')
ax.set_title('Separation Velocity (70 ns Configuration)')
plt.savefig('/Users/zrollins/Documents/Documents/TCR_glyco/glyco/70/Vel.png')
plt.show()

#Plot H-Bond Frequency
    #Find max_v, max_t
max_v= 0.0010
df4 = df3.loc[df3['Instantaneous Velocity SMA'] >= max_v]
max_t=df4.values[0,0]
    #Partition H-Bonds & Time
df5 = df.drop(df[df['Time (ps)'] >= max_t].index)
h_tot = df5['TCR_MHC']+ df5['TCR_MART1'] + df5['TCR_Glycans'] + df5['MHC_Glycans'] + df5['MART1_Glycans'] +df5['Glycan_Glycan']
df5['Total_Hs'] = h_tot
df8 = df5.groupby('Total_Hs')['Time (ps)'].size().reset_index(name='Total Time (ps)')
df8['H-Bond Frequency (pMHC)']= df8['Total Time (ps)']/max_t
df8.to_excel('/Users/zrollins/Documents/Documents/TCR_glyco/glyco/70/hfrequency.xlsx')
print (df8)
# Out:
# 12139
# 12139
#     Total_Hs  Total Time (ps)  H-Bond Frequency (pMHC)
# 0        0.0              844                 0.075364
# 1        1.0              750                 0.066970
# 2        2.0              843                 0.075275
# 3        3.0             1211                 0.108135
# 4        4.0             1564                 0.139655
# 5        5.0             1610                 0.143763
# 6        6.0             1634                 0.145906
# 7        7.0             1312                 0.117153
# 8        8.0              832                 0.074292
# 9        9.0              385                 0.034378
# 10      10.0              156                 0.013930
# 11      11.0               42                 0.003750
# 12      12.0               11                 0.000982
# 13      13.0                5                 0.000446

# %%
#100 ns

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

#Position vs Time
x1, t1 = [], []

with open("/Users/zrollins/Documents/Documents/TCR_glyco/dglyco/50/pullxcf.xvg") as f:
    #lines = (line for line in f if not line.startsiwith('#') if not line.startswith('$'))
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            t1.append(float(cols[0]))
            x1.append(float(cols[1]))
x = x1[::10]

#TCR-MHC H_Number vs Time

t, ha, haa = [], [], []

with open("/Users/zrollins/Documents/Documents/TCR_glyco/dglyco/50/num_interface_TCR_MHC.xvg") as f:
    #lines = (line for line in f if not line.startsiwith('#') if not line.startswith('$'))
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 3:
            t.append(float(cols[0]))
            ha.append(float(cols[1]))
            haa.append(float(cols[2]))



#TCR-peptide H_Number vs Time

t, hc, hcc = [], [], []

with open("/Users/zrollins/Documents/Documents/TCR_glyco/dglyco/50/num_interface_TCR_pep.xvg") as f:
    #lines = (line for line in f if not line.startsiwith('#') if not line.startswith('$'))
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 3:
            t.append(float(cols[0]))
            hc.append(float(cols[1]))
            hcc.append(float(cols[2]))
            

#PLOT Hbonds vs Time

hbonds = {'Time (ps)': t,'TCR_MART1':hc,'TCR_MHC':ha}
df = pd.DataFrame(hbonds)
df['TCR_MART1 SMA']= df.iloc[:,1].rolling(window=200).mean()
df['TCR_MHC SMA']= df.iloc[:,2].rolling(window=200).mean()
ax = plt.gca()
df.plot(kind='line',x='Time (ps)', y='TCR_MART1 SMA', color='magenta', ax=ax)
df.plot(kind='line',x='Time (ps)', y='TCR_MHC SMA', color= 'blue', ax=ax)
ax.set_ylabel('Number of Hyrogen Bonds')
ax.set_title('H-Bonds vs Time (50 ns Configuration)')
plt.savefig('/Users/zrollins/Documents/Documents/TCR_glyco/dglyco/50/HT.png')
plt.show()


#PLOT Hbonds vs COM Distance
print (len(ha))
print (len(x))
ha1 = ha[:len(ha)-9]
hc1 = hc[:len(hc)-9]


hbonds2 = {'COM Distance (nm)':x, 'TCR_MART1':hc1,'TCR_MHC':ha1}
df2 = pd.DataFrame(hbonds2)
df2.to_excel('/Users/zrollins/Documents/Documents/TCR_glyco/dglyco/50/hx.xlsx')
df2['Peptide']= df.iloc[:,1].rolling(window=1).mean()
df2['MHC']= df.iloc[:,2].rolling(window=1).mean()
ax = plt.gca()
df2.plot(kind='line',x='COM Distance (nm)', y='TCR_MART1', color='magenta', ax=ax)
df2.plot(kind='line',x='COM Distance (nm)', y='TCR_MHC', color= 'blue', ax=ax)
ax.set_xlim(6,7.5)
ax.set_ylabel('Number of Hyrogen Bonds')
ax.set_title('H-Bonds vs Distance (50 ns Configuration)')
plt.savefig('/Users/zrollins/Documents/Documents/TCR_glyco/dglyco/50/HX.png')
plt.show()

#Plot Separation Velocity vs Time
vel = []
vel = np.gradient(x1)
acc = []
acc = np.gradient(vel)
v = {'Time (ps)':t1, 'COM Distance (nm)':x1, 'Instantaneous Velocity':vel, 'Instant Acceleration':acc}
df3 = pd.DataFrame(v)
df3['Instantaneous Velocity SMA']= df3.iloc[:,2].rolling(window=1000).mean()
ax = plt.gca()
df3.plot(kind='line',x='Time (ps)', y='Instantaneous Velocity SMA', color='black', ax=ax)
ax.set_ylabel('Velocity (nm/ps)')
ax.set_title('Separation Velocity (50 ns Configuration)')
plt.savefig('/Users/zrollins/Documents/Documents/TCR_glyco/dglyco/50/Vel.png')
plt.show()

#Plot H-Bond Frequency
    #Find max_v, max_t
max_v= 0.0010
df4 = df3.loc[df3['Instantaneous Velocity SMA'] >= max_v]
max_t=df4.values[0,0]
    #Partition H-Bonds & Time
df5 = df.drop(df[df['Time (ps)'] >= max_t].index)
h_tot = df5['TCR_MHC']+ df5['TCR_MART1'] 
df5['Total_Hs'] = h_tot
df8 = df5.groupby('Total_Hs')['Time (ps)'].size().reset_index(name='Total Time (ps)')
df8['H-Bond Frequency (pMHC)']= df8['Total Time (ps)']/max_t
df8.to_excel('/Users/zrollins/Documents/Documents/TCR_glyco/dglyco/50/hfrequency.xlsx')
print (df8)
# Out:
# 11377
# 11368
#    Total_Hs  Total Time (ps)  H-Bond Frequency (pMHC)
# 0       0.0              816                 0.074170
# 1       1.0             1604                 0.145796
# 2       2.0             2816                 0.255960
# 3       3.0             3033                 0.275685
# 4       4.0             1628                 0.147977
# 5       5.0              661                 0.060082
# 6       6.0              318                 0.028905
# 7       7.0              109                 0.009908
# 8       8.0               15                 0.001363
# 9       9.0                2                 0.000182

# %%
#100 ns

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

#Position vs Time
x1, t1 = [], []

with open("/Users/zrollins/Documents/Documents/TCR_glyco/dglyco/60/pullxcf.xvg") as f:
    #lines = (line for line in f if not line.startsiwith('#') if not line.startswith('$'))
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            t1.append(float(cols[0]))
            x1.append(float(cols[1]))
x = x1[::10]

#TCR-MHC H_Number vs Time

t, ha, haa = [], [], []

with open("/Users/zrollins/Documents/Documents/TCR_glyco/dglyco/60/num_interface_TCR_MHC.xvg") as f:
    #lines = (line for line in f if not line.startsiwith('#') if not line.startswith('$'))
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 3:
            t.append(float(cols[0]))
            ha.append(float(cols[1]))
            haa.append(float(cols[2]))



#TCR-peptide H_Number vs Time

t, hc, hcc = [], [], []

with open("/Users/zrollins/Documents/Documents/TCR_glyco/dglyco/60/num_interface_TCR_pep.xvg") as f:
    #lines = (line for line in f if not line.startsiwith('#') if not line.startswith('$'))
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 3:
            t.append(float(cols[0]))
            hc.append(float(cols[1]))
            hcc.append(float(cols[2]))
            

#PLOT Hbonds vs Time

hbonds = {'Time (ps)': t,'TCR_MART1':hc,'TCR_MHC':ha}
df = pd.DataFrame(hbonds)
df['TCR_MART1 SMA']= df.iloc[:,1].rolling(window=200).mean()
df['TCR_MHC SMA']= df.iloc[:,2].rolling(window=200).mean()
ax = plt.gca()
df.plot(kind='line',x='Time (ps)', y='TCR_MART1 SMA', color='magenta', ax=ax)
df.plot(kind='line',x='Time (ps)', y='TCR_MHC SMA', color= 'blue', ax=ax)
ax.set_ylabel('Number of Hyrogen Bonds')
ax.set_title('H-Bonds vs Time (60 ns Configuration)')
plt.savefig('/Users/zrollins/Documents/Documents/TCR_glyco/dglyco/60/HT.png')
plt.show()


#PLOT Hbonds vs COM Distance
print (len(ha))
print (len(x))
ha1 = ha[:len(ha)-17]
hc1 = hc[:len(hc)-17]


hbonds2 = {'COM Distance (nm)':x, 'TCR_MART1':hc1,'TCR_MHC':ha1}
df2 = pd.DataFrame(hbonds2)
df2.to_excel('/Users/zrollins/Documents/Documents/TCR_glyco/dglyco/60/hx.xlsx')
df2['Peptide']= df.iloc[:,1].rolling(window=1).mean()
df2['MHC']= df.iloc[:,2].rolling(window=1).mean()
ax = plt.gca()
df2.plot(kind='line',x='COM Distance (nm)', y='TCR_MART1', color='magenta', ax=ax)
df2.plot(kind='line',x='COM Distance (nm)', y='TCR_MHC', color= 'blue', ax=ax)
ax.set_xlim(6,7.5)
ax.set_ylabel('Number of Hyrogen Bonds')
ax.set_title('H-Bonds vs Distance (60 ns Configuration)')
plt.savefig('/Users/zrollins/Documents/Documents/TCR_glyco/dglyco/60/HX.png')
plt.show()

#Plot Separation Velocity vs Time
vel = []
vel = np.gradient(x1)
acc = []
acc = np.gradient(vel)
v = {'Time (ps)':t1, 'COM Distance (nm)':x1, 'Instantaneous Velocity':vel, 'Instant Acceleration':acc}
df3 = pd.DataFrame(v)
df3['Instantaneous Velocity SMA']= df3.iloc[:,2].rolling(window=1000).mean()
ax = plt.gca()
df3.plot(kind='line',x='Time (ps)', y='Instantaneous Velocity SMA', color='black', ax=ax)
ax.set_ylabel('Velocity (nm/ps)')
ax.set_title('Separation Velocity (60 ns Configuration)')
plt.savefig('/Users/zrollins/Documents/Documents/TCR_glyco/dglyco/60/Vel.png')
plt.show()

#Plot H-Bond Frequency
    #Find max_v, max_t
max_v= 0.0010
df4 = df3.loc[df3['Instantaneous Velocity SMA'] >= max_v]
max_t=df4.values[0,0]
    #Partition H-Bonds & Time
df5 = df.drop(df[df['Time (ps)'] >= max_t].index)
h_tot = df5['TCR_MHC']+ df5['TCR_MART1'] 
df5['Total_Hs'] = h_tot
df8 = df5.groupby('Total_Hs')['Time (ps)'].size().reset_index(name='Total Time (ps)')
df8['H-Bond Frequency (pMHC)']= df8['Total Time (ps)']/max_t
df8.to_excel('/Users/zrollins/Documents/Documents/TCR_glyco/dglyco/60/hfrequency.xlsx')
print (df8)
# Out:
# 4636
# 4619
#    Total_Hs  Total Time (ps)  H-Bond Frequency (pMHC)
# 0       0.0              824                 0.193219
# 1       1.0              182                 0.042677
# 2       2.0              335                 0.078554
# 3       3.0              699                 0.163908
# 4       4.0              909                 0.213150
# 5       5.0              778                 0.182432
# 6       6.0              421                 0.098720
# 7       7.0              110                 0.025794
# 8       8.0                7                 0.001641

# %%
#100 ns

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

#Position vs Time
x1, t1 = [], []

with open("/Users/zrollins/Documents/Documents/TCR_glyco/dglyco/70/pullxcf.xvg") as f:
    #lines = (line for line in f if not line.startsiwith('#') if not line.startswith('$'))
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            t1.append(float(cols[0]))
            x1.append(float(cols[1]))
x = x1[::10]

#TCR-MHC H_Number vs Time

t, ha, haa = [], [], []

with open("/Users/zrollins/Documents/Documents/TCR_glyco/dglyco/70/num_interface_TCR_MHC.xvg") as f:
    #lines = (line for line in f if not line.startsiwith('#') if not line.startswith('$'))
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 3:
            t.append(float(cols[0]))
            ha.append(float(cols[1]))
            haa.append(float(cols[2]))



#TCR-peptide H_Number vs Time

t, hc, hcc = [], [], []

with open("/Users/zrollins/Documents/Documents/TCR_glyco/dglyco/70/num_interface_TCR_pep.xvg") as f:
    #lines = (line for line in f if not line.startsiwith('#') if not line.startswith('$'))
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 3:
            t.append(float(cols[0]))
            hc.append(float(cols[1]))
            hcc.append(float(cols[2]))
            

#PLOT Hbonds vs Time

hbonds = {'Time (ps)': t,'TCR_MART1':hc,'TCR_MHC':ha}
df = pd.DataFrame(hbonds)
df['TCR_MART1 SMA']= df.iloc[:,1].rolling(window=200).mean()
df['TCR_MHC SMA']= df.iloc[:,2].rolling(window=200).mean()
ax = plt.gca()
df.plot(kind='line',x='Time (ps)', y='TCR_MART1 SMA', color='magenta', ax=ax)
df.plot(kind='line',x='Time (ps)', y='TCR_MHC SMA', color= 'blue', ax=ax)
ax.set_ylabel('Number of Hyrogen Bonds')
ax.set_title('H-Bonds vs Time (70 ns Configuration)')
plt.savefig('/Users/zrollins/Documents/Documents/TCR_glyco/dglyco/70/HT.png')
plt.show()


#PLOT Hbonds vs COM Distance
print (len(ha))
print (len(x))
ha1 = ha[:len(ha)-20]
hc1 = hc[:len(hc)-20]


hbonds2 = {'COM Distance (nm)':x, 'TCR_MART1':hc1,'TCR_MHC':ha1}
df2 = pd.DataFrame(hbonds2)
df2.to_excel('/Users/zrollins/Documents/Documents/TCR_glyco/dglyco/70/hx.xlsx')
df2['Peptide']= df.iloc[:,1].rolling(window=1).mean()
df2['MHC']= df.iloc[:,2].rolling(window=1).mean()
ax = plt.gca()
df2.plot(kind='line',x='COM Distance (nm)', y='TCR_MART1', color='magenta', ax=ax)
df2.plot(kind='line',x='COM Distance (nm)', y='TCR_MHC', color= 'blue', ax=ax)
ax.set_xlim(6,7.5)
ax.set_ylabel('Number of Hyrogen Bonds')
ax.set_title('H-Bonds vs Distance (70 ns Configuration)')
plt.savefig('/Users/zrollins/Documents/Documents/TCR_glyco/dglyco/70/HX.png')
plt.show()

#Plot Separation Velocity vs Time
vel = []
vel = np.gradient(x1)
acc = []
acc = np.gradient(vel)
v = {'Time (ps)':t1, 'COM Distance (nm)':x1, 'Instantaneous Velocity':vel, 'Instant Acceleration':acc}
df3 = pd.DataFrame(v)
df3['Instantaneous Velocity SMA']= df3.iloc[:,2].rolling(window=1000).mean()
ax = plt.gca()
df3.plot(kind='line',x='Time (ps)', y='Instantaneous Velocity SMA', color='black', ax=ax)
ax.set_ylabel('Velocity (nm/ps)')
ax.set_title('Separation Velocity (70 ns Configuration)')
plt.savefig('/Users/zrollins/Documents/Documents/TCR_glyco/dglyco/70/Vel.png')
plt.show()

#Plot H-Bond Frequency
    #Find max_v, max_t
max_v= 0.0010
df4 = df3.loc[df3['Instantaneous Velocity SMA'] >= max_v]
max_t=df4.values[0,0]
    #Partition H-Bonds & Time
df5 = df.drop(df[df['Time (ps)'] >= max_t].index)
h_tot = df5['TCR_MHC']+ df5['TCR_MART1'] 
df5['Total_Hs'] = h_tot
df8 = df5.groupby('Total_Hs')['Time (ps)'].size().reset_index(name='Total Time (ps)')
df8['H-Bond Frequency (pMHC)']= df8['Total Time (ps)']/max_t
df8.to_excel('/Users/zrollins/Documents/Documents/TCR_glyco/dglyco/70/hfrequency.xlsx')
print (df8)
# Out:
# 6652
# 6632
#    Total_Hs  Total Time (ps)  H-Bond Frequency (pMHC)
# 0       0.0              820                 0.132645
# 1       1.0             1116                 0.180527
# 2       2.0             1927                 0.311716
# 3       3.0             1332                 0.215468
# 4       4.0              529                 0.085572
# 5       5.0              349                 0.056455
# 6       6.0               97                 0.015691
# 7       7.0               12                 0.001941

# %%
#FFT Denoise
#Equilibration

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid.inset_locator import (inset_axes, InsetPosition,
                                                  mark_inset)

#TCR-MHC H_Number vs Time

t, ha, haa = [], [], []

with open("/Users/zrollins/Documents/Documents/TCR_glyco/glyco/70/num_interface_TCR_MHC.xvg") as f:
    #lines = (line for line in f if not line.startsiwith('#') if not line.startswith('$'))
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 3:
            t.append(float(cols[0]))
            ha.append(float(cols[1]))
            haa.append(float(cols[2]))



#TCR-peptide H_Number vs Time

t, hc, hcc = [], [], []

with open("/Users/zrollins/Documents/Documents/TCR_glyco/glyco/70/num_interface_TCR_pep.xvg") as f:
    #lines = (line for line in f if not line.startsiwith('#') if not line.startswith('$'))
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 3:
            t.append(float(cols[0]))
            hc.append(float(cols[1]))
            hcc.append(float(cols[2]))


#95 ns
#TCR-MHC H_Number vs Time

t1, ha1, haa1 = [], [], []

with open("/Users/zrollins/Documents/Documents/TCR_glyco/glyco/60/num_interface_TCR_MHC.xvg") as f:
    #lines = (line for line in f if not line.startsiwith('#') if not line.startswith('$'))
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 3:
            t1.append(float(cols[0]))
            ha1.append(float(cols[1]))
            haa1.append(float(cols[2]))



#TCR-peptide H_Number vs Time

t1, hc1, hcc1 = [], [], []

with open("/Users/zrollins/Documents/Documents/TCR_glyco/glyco/60/num_interface_TCR_pep.xvg") as f:
    #lines = (line for line in f if not line.startsiwith('#') if not line.startswith('$'))
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 3:
            t1.append(float(cols[0]))
            hc1.append(float(cols[1]))
            hcc1.append(float(cols[2]))
            
#90 ns
#TCR-MHC H_Number vs Time

t2, ha2, haa2 = [], [], []

with open("/Users/zrollins/Documents/Documents/TCR_glyco/glyco/50/num_interface_TCR_MHC.xvg") as f:
    #lines = (line for line in f if not line.startsiwith('#') if not line.startswith('$'))
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 3:
            t2.append(float(cols[0]))
            ha2.append(float(cols[1]))
            haa2.append(float(cols[2]))



#TCR-peptide H_Number vs Time

t2, hc2, hcc2 = [], [], []

with open("/Users/zrollins/Documents/Documents/TCR_glyco/glyco/50/num_interface_TCR_pep.xvg") as f:
    #lines = (line for line in f if not line.startsiwith('#') if not line.startswith('$'))
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 3:
            t2.append(float(cols[0]))
            hc2.append(float(cols[1]))
            hcc2.append(float(cols[2]))
            
# FFT EQ vs Pulls
h = ha + hc
h1 = ha1 + hc1
h2 = ha2 + hc2
dt=0.001
n = len(t)
n1 = len(t1)
n2 = len(t2)
fhat=np.fft.fft(h,n)
fhat1=np.fft.fft(h1,n1)
fhat2=np.fft.fft(h2,n2)
PSD = fhat * np.conj(fhat) / n
PSD1 = fhat1 * np.conj(fhat1) / n1
PSD2 = fhat2 * np.conj(fhat2) / n2
freq = (1/(dt*n)) * np.arange(n)
freq1 = (1/(dt*n1))*np.arange(n1)
freq2 = (1/(dt*n2))*np.arange(n2)
L = np.arange(1, np.floor(n/2), dtype='int')
L1 = np.arange(1, np.floor(n1/2), dtype='int')
L2 = np.arange(1, np.floor(n2/2), dtype='int')

fig,axs = plt.subplots(1,1)

plt.plot(freq[L],PSD[L], color='orangered',LineWidth=2,label='70 ns')
plt.plot(freq1[L1],PSD1[L1], color='orange',LineWidth=2,label='60 ns')
plt.plot(freq2[L2],PSD2[L2], color='wheat',LineWidth=2,label='50 ns')
#plt.plot(freqeq[Leq],PSDeq[Leq], color='black',LineWidth=2,label='EQ')
plt.xlim(freq[L[0]],freq[L[-1]])
plt.xlim(0,10)
plt.ylim(0,5000)
plt.legend()
plt.xticks(fontsize=25)
plt.yticks(fontsize=25)
plt.xlabel('Frequency (GHz)', fontname = 'Arial', fontsize=30)
plt.ylabel('Amplitude (AU)', fontname = 'Arial', fontsize=30)
#plt.title('Glycosylated TCR-pMHC H-Bonding Power Spectral Density', fontname = 'Arial Black', fontsize=30)

ax2 = plt.axes([0,0,1,1])
ip = InsetPosition(axs, [0.4,0.4,0.5,0.5])
ax2.set_axes_locator(ip)
mark_inset(axs, ax2, loc1=2,loc2=4, fc="none",ec='0.5')

ax2.plot(freq[L],PSD[L], color='orangered',LineWidth=2,label='70 ns')
ax2.plot(freq1[L1],PSD1[L1], color='orange',LineWidth=2,label='60 ns')
ax2.plot(freq2[L2],PSD2[L2], color='wheat',LineWidth=2,label='50 ns')
ax2.set_xlim(0,2)
ax2.set_ylim(0,1000)

fig.set_figheight(10)
fig.set_figwidth(12)
fig.tight_layout()
plt.savefig('/Users/zrollins/Documents/Documents/TCR_glyco/glyco/PSD_h.png',dpi=300)
plt.show()
# Out:
# /var/folders/sl/5t2qrktn4rb09_gfhrrlqc180000gn/T/ipykernel_37708/403450411.py:150: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   plt.plot(freq[L],PSD[L], color='orangered',LineWidth=2,label='70 ns')
# /usr/local/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:102: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# /var/folders/sl/5t2qrktn4rb09_gfhrrlqc180000gn/T/ipykernel_37708/403450411.py:151: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   plt.plot(freq1[L1],PSD1[L1], color='orange',LineWidth=2,label='60 ns')
# /usr/local/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:102: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# ...

# %%
#FFT Denoise
#Equilibration

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid.inset_locator import (inset_axes, InsetPosition,
                                                  mark_inset)

#TCR-MHC H_Number vs Time

t, ha, haa = [], [], []

with open("/Users/zrollins/Documents/Documents/TCR_glyco/dglyco/70/num_interface_TCR_MHC.xvg") as f:
    #lines = (line for line in f if not line.startsiwith('#') if not line.startswith('$'))
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 3:
            t.append(float(cols[0]))
            ha.append(float(cols[1]))
            haa.append(float(cols[2]))



#TCR-peptide H_Number vs Time

t, hc, hcc = [], [], []

with open("/Users/zrollins/Documents/Documents/TCR_glyco/dglyco/70/num_interface_TCR_pep.xvg") as f:
    #lines = (line for line in f if not line.startsiwith('#') if not line.startswith('$'))
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 3:
            t.append(float(cols[0]))
            hc.append(float(cols[1]))
            hcc.append(float(cols[2]))


#95 ns
#TCR-MHC H_Number vs Time

t1, ha1, haa1 = [], [], []

with open("/Users/zrollins/Documents/Documents/TCR_glyco/dglyco/60/num_interface_TCR_MHC.xvg") as f:
    #lines = (line for line in f if not line.startsiwith('#') if not line.startswith('$'))
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 3:
            t1.append(float(cols[0]))
            ha1.append(float(cols[1]))
            haa1.append(float(cols[2]))



#TCR-peptide H_Number vs Time

t1, hc1, hcc1 = [], [], []

with open("/Users/zrollins/Documents/Documents/TCR_glyco/dglyco/60/num_interface_TCR_pep.xvg") as f:
    #lines = (line for line in f if not line.startsiwith('#') if not line.startswith('$'))
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 3:
            t1.append(float(cols[0]))
            hc1.append(float(cols[1]))
            hcc1.append(float(cols[2]))
            
#90 ns
#TCR-MHC H_Number vs Time

t2, ha2, haa2 = [], [], []

with open("/Users/zrollins/Documents/Documents/TCR_glyco/dglyco/50/num_interface_TCR_MHC.xvg") as f:
    #lines = (line for line in f if not line.startsiwith('#') if not line.startswith('$'))
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 3:
            t2.append(float(cols[0]))
            ha2.append(float(cols[1]))
            haa2.append(float(cols[2]))



#TCR-peptide H_Number vs Time

t2, hc2, hcc2 = [], [], []

with open("/Users/zrollins/Documents/Documents/TCR_glyco/dglyco/50/num_interface_TCR_pep.xvg") as f:
    #lines = (line for line in f if not line.startsiwith('#') if not line.startswith('$'))
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 3:
            t2.append(float(cols[0]))
            hc2.append(float(cols[1]))
            hcc2.append(float(cols[2]))
            
# FFT EQ vs Pulls
h = ha + hc
h1 = ha1 + hc1
h2 = ha2 + hc2
dt=0.001
n = len(t)
n1 = len(t1)
n2 = len(t2)
fhat=np.fft.fft(h,n)
fhat1=np.fft.fft(h1,n1)
fhat2=np.fft.fft(h2,n2)
PSD = fhat * np.conj(fhat) / n
PSD1 = fhat1 * np.conj(fhat1) / n1
PSD2 = fhat2 * np.conj(fhat2) / n2
freq = (1/(dt*n)) * np.arange(n)
freq1 = (1/(dt*n1))*np.arange(n1)
freq2 = (1/(dt*n2))*np.arange(n2)
L = np.arange(1, np.floor(n/2), dtype='int')
L1 = np.arange(1, np.floor(n1/2), dtype='int')
L2 = np.arange(1, np.floor(n2/2), dtype='int')

fig,axs = plt.subplots(1,1)

plt.plot(freq[L],PSD[L], color='black',LineWidth=2,label='70 ns')
plt.plot(freq1[L1],PSD1[L1], color='slategray',LineWidth=2,label='60 ns')
plt.plot(freq2[L2],PSD2[L2], color='lightgrey',LineWidth=2,label='50 ns')
#plt.plot(freqeq[Leq],PSDeq[Leq], color='black',LineWidth=2,label='EQ')
plt.xlim(freq[L[0]],freq[L[-1]])
plt.xlim(0,10)
plt.ylim(0,5000)
plt.legend()
plt.xticks(fontsize=25)
plt.yticks(fontsize=25)
plt.xlabel('Frequency (GHz)', fontname = 'Arial', fontsize=30)
plt.ylabel('Amplitude (AU)', fontname = 'Arial', fontsize=30)
#plt.title('Glycosylated TCR-pMHC H-Bonding Power Spectral Density', fontname = 'Arial Black', fontsize=30)

ax2 = plt.axes([0,0,1,1])
ip = InsetPosition(axs, [0.4,0.4,0.5,0.5])
ax2.set_axes_locator(ip)
mark_inset(axs, ax2, loc1=2,loc2=4, fc="none",ec='0.5')

ax2.plot(freq[L],PSD[L], color='black',LineWidth=2,label='70 ns')
ax2.plot(freq1[L1],PSD1[L1], color='slategray',LineWidth=2,label='60 ns')
ax2.plot(freq2[L2],PSD2[L2], color='lightgrey',LineWidth=2,label='50 ns')
ax2.set_xlim(0,2)
ax2.set_ylim(0,1000)

fig.set_figheight(10)
fig.set_figwidth(12)
fig.tight_layout()
plt.savefig('/Users/zrollins/Documents/Documents/TCR_glyco/dglyco/PSD_h.png',dpi=300)
plt.show()
# Out:
# /var/folders/sl/5t2qrktn4rb09_gfhrrlqc180000gn/T/ipykernel_4499/1167236542.py:150: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   plt.plot(freq[L],PSD[L], color='black',LineWidth=2,label='70 ns')
# /usr/local/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:102: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# /var/folders/sl/5t2qrktn4rb09_gfhrrlqc180000gn/T/ipykernel_4499/1167236542.py:151: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   plt.plot(freq1[L1],PSD1[L1], color='slategray',LineWidth=2,label='60 ns')
# /usr/local/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:102: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# ...
